# %% [markdown]
# Copyright Jana Schaich Borg/Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)

# %% [markdown]
# # MySQL Exercise 5: Summaries of Groups of Data
#
# So far you've learned how to select, reformat, manipulate, order, and summarize data from a single table in database.  In this lesson, you are going to learn how to summarize multiple subsets of your data in the same query.  The method for doing this is to include a "GROUP BY" clause in your SQL query.
#
#
#
# ## The GROUP BY clause
#
# The GROUP BY clause comes after the WHERE clause, but before ORDER BY or LIMIT:
#
# <img src="https://duke.box.com/shared/static/lc0yjfz1339q3mc04ne13m2q5tkzy3x7.jpg" width=400 alt="SELECT FROM WHERE ORDER BY" />
#
# The GROUP BY clause is easy to incorporate into your queries.  In fact, it might be a little too easy to incorporate into MySQL queries, because it can be used incorrectly in MySQL queries even when no error message is displayed.  As a consequence, I suggest you adopt a healthy dose of caution every time you use the GROUP BY clause.  By the end of this lesson, you will understand why.  When used correctly, though, GROUP BY is one of the most useful and efficient parts of an SQL query, and once you are comfortable using it, you will use it very frequently.
#
# **To get started, load the SQL library and the Dognition database, and set the dognition database as the default:**

# %%
# %load_ext sql
# %sql mysql://studentuser:studentpw@mysqlserver/dognitiondb
# %sql USE dognitiondb
# Out:
# 0 rows affected.
# []

# %% [markdown]
# Let's return to a question from MySQL Exercise 4.  How would you query the average rating for each of the 40 tests in the Reviews table? As we discussed, one very inefficient method to do that would be to write 40 separate queries with each one having a different test name in the WHERE conditional clause.  Then you could copy or transcribe the results from all 40 queries into one place.  But that wouldn't be very pleasant.  Here's how you could do the same thing using one query that has a GROUP BY clause:
#
# ```mySQL
# SELECT test_name, AVG(rating) AS AVG_Rating
# FROM reviews
# GROUP BY test_name
# ```
#
# This query will output the average rating for each test.  More technically, this query will instruct MySQL to average all the rows that have the same value in the test_name column.
#
# Notice that I included test_name in the SELECT statement.  As a strong rule of thumb, if you are grouping by a column, you should also include that column in the SELECT statement.  If you don't do this, you won't know to which group each row of your output corresponds.
#
# **To see what I mean, try the query above without test_name included in the SELECT statement:**

# %%
# %%sql
# SELECT test_name, AVG(rating) AS AVG_Rating
# FROM reviews
# GROUP BY test_name;
# Out:
# 40 rows affected.
# [('1 vs 1 Game', Decimal('3.9206')),
#  ('3 vs 1 Game', Decimal('4.2857')),
#  ('5 vs 1 Game', Decimal('3.9272')),
#  ('Arm Pointing', Decimal('4.2153')),
#  ('Cover Your Eyes', Decimal('2.6741')),
#  ('Delayed Cup Game', Decimal('3.3514')),
#  ('Different Perspective', Decimal('2.7647')),
#  ('Expression Game', Decimal('4.0000')),
#  ('Eye Contact Game', Decimal('2.9372')),
#  ('Eye Contact Warm-up', Decimal('0.9632')),
#  ('Foot Pointing', Decimal('4.0093')),
#  ('Impossible Task Game', Decimal('3.0965')),
#  ('Impossible Task Warm-up', Decimal('0.2174')),
#  ('Inferential Reasoning Game', Decimal('4.5223')),
#  ('Inferential Reasoning Warm-up', Decimal('4.3066')),
#  ('Memory versus Pointing', Decimal('3.5584')),
#  ('Memory versus Smell', Decimal('4.2623')),
#  ('Navigation Game', Decimal('2.9841')),
#  ('Navigation Learning', Decimal('2.0303')),
#  ('Navigation Warm-up', Decimal('1.9805')),
#  ('Numerosity Warm-Up', Decimal('2.6173')),
#  ('One Cup Warm-up', Decimal('1.3693')),
#  ('Physical Reasoning Game', Decimal('3.8492')),
#  ('Physical Reasoning Warm-up', Decimal('1.6625')),
#  ('Self Control Game', Decimal('3.8519')),
#  ('Shaker Game', Decimal('4.6667')),
#  ('Shaker Warm-Up', Decimal('2.1818')),
#  ('Shared Perspective', Decimal('3.2778')),
#  ('Slide', Decimal('4.5111')),
#  ('Smell Game', Decimal('4.2857')),
#  ('Stair Game', Decimal('4.2857')),
#  ('Switch', Decimal('5.5676')),
#  ('Treat Warm-up', Decimal('0.7909')),
#  ('Turn Your Back', Decimal('3.1293')),
#  ('Two Cup Warm-up', Decimal('1.6737')),
#  ('Warm-Up', Decimal('1.2020')),
#  ('Watching', Decimal('2.4594')),
#  ('Watching - Part 2', Decimal('2.6570')),
#  ('Yawn Game', Decimal('2.8477')),
#  ('Yawn Warm-up', Decimal('2.0035'))]

# %% [markdown]
# You can form groups using derived values as well as original columns.  To illustrate this, let's address another question: how many tests were completed during each month of the year?
#
# To answer this question, we need to take advantage of another datetime function described in the website below:
#
# http://www.w3resource.com/mysql/date-and-time-functions/date-and-time-functions.php
#
# MONTH() will return a number representing the month of a date entry. To get the total number of tests completed each month, you could put the MONTH function into the GROUP BY clause, in this case through an alias:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY Month;
# ```
#
# You can also group by multiple columns or derived fields.  If we wanted to determine the total number of each type of test completed each month, you could include both "test_name" and the derived "Month" field in the GROUP BY clause, separated by a comma.
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, Month;
# ```
#
# MySQL allows you to use aliases in a GROUP BY clause, but some database systems do not.  If you are using a database system that does NOT accept aliases in GROUP BY clauses, you can still group by derived fields, but you have to duplicate the calculation for the derived field in the GROUP BY clause in addition to including the derived field in the SELECT clause:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, MONTH(created_at);
# ```
#
# Try the query once with test_name first in the GROUP BY list, and once with Month first in the GROUP BY list below.  Inspect the outputs:

# %%
# %%sql
# SELECT test_name, MONTH(created_at) AS MONTH, COUNT(created_at) AS NUM_completed
# FROM complete_tests
# GROUP BY test_name, MONTH;
# Out:
# 480 rows affected.
# [('1 vs 1 Game', 1, 25),
#  ('1 vs 1 Game', 2, 28),
#  ('1 vs 1 Game', 3, 22),
#  ('1 vs 1 Game', 4, 12),
#  ('1 vs 1 Game', 5, 13),
#  ('1 vs 1 Game', 6, 18),
#  ('1 vs 1 Game', 7, 36),
#  ('1 vs 1 Game', 8, 17),
#  ('1 vs 1 Game', 9, 28),
#  ('1 vs 1 Game', 10, 27),
#  ('1 vs 1 Game', 11, 15),
#  ('1 vs 1 Game', 12, 14),
#  ('3 vs 1 Game', 1, 35),
#  ('3 vs 1 Game', 2, 28),
#  ('3 vs 1 Game', 3, 34),
#  ('3 vs 1 Game', 4, 16),
#  ('3 vs 1 Game', 5, 34),
#  ('3 vs 1 Game', 6, 42),
#  ('3 vs 1 Game', 7, 37),
#  ('3 vs 1 Game', 8, 23),
#  ('3 vs 1 Game', 9, 24),
#  ('3 vs 1 Game', 10, 28),
#  ('3 vs 1 Game', 11, 22),
#  ('3 vs 1 Game', 12, 45),
#  ('5 vs 1 Game', 1, 59),
#  ('5 vs 1 Game', 2, 54),
#  ('5 vs 1 Game', 3, 57),
#  ('5 vs 1 Game', 4, 29),
#  ('5 vs 1 Game', 5, 50),
#  ('5 vs 1 Game', 6, 61),
#  ('5 vs 1 Game', 7, 69),
#  ('5 vs 1 Game', 8, 38),
#  ('5 vs 1 Game', 9, 50),
#  ('5 vs 1 Game', 10, 54),
#  ('5 vs 1 Game', 11, 40),
#  ('5 vs 1 Game', 12, 59),
#  ('Arm Pointing', 1, 622),
#  ('Arm Pointing', 2, 498),
#  ('Arm Pointing', 3, 507),
#  ('Arm Pointing', 4, 381),
#  ('Arm Pointing', 5, 1149),
#  ('Arm Pointing', 6, 1424),
#  ('Arm Pointing', 7, 913),
#  ('Arm Pointing', 8, 779),
#  ('Arm Pointing', 9, 1243),
#  ('Arm Pointing', 10, 2535),
#  ('Arm Pointing', 11, 735),
#  ('Arm Pointing', 12, 666),
#  ('Cover Your Eyes', 1, 452),
#  ('Cover Your Eyes', 2, 373),
#  ('Cover Your Eyes', 3, 416),
#  ('Cover Your Eyes', 4, 291),
#  ('Cover Your Eyes', 5, 753),
#  ('Cover Your Eyes', 6, 767),
#  ('Cover Your Eyes', 7, 521),
#  ('Cover Your Eyes', 8, 408),
#  ('Cover Your Eyes', 9, 574),
#  ('Cover Your Eyes', 10, 1653),
#  ('Cover Your Eyes', 11, 595),
#  ('Cover Your Eyes', 12, 447),
#  ('Delayed Cup Game', 1, 356),
#  ('Delayed Cup Game', 2, 319),
#  ('Delayed Cup Game', 3, 350),
#  ('Delayed Cup Game', 4, 256),
#  ('Delayed Cup Game', 5, 539),
#  ('Delayed Cup Game', 6, 525),
#  ('Delayed Cup Game', 7, 407),
#  ('Delayed Cup Game', 8, 355),
#  ('Delayed Cup Game', 9, 424),
#  ('Delayed Cup Game', 10, 1019),
#  ('Delayed Cup Game', 11, 422),
#  ('Delayed Cup Game', 12, 299),
#  ('Different Perspective', 1, 2),
#  ('Different Perspective', 2, 3),
#  ('Different Perspective', 3, 4),
#  ('Different Perspective', 4, 8),
#  ('Different Perspective', 5, 12),
#  ('Different Perspective', 6, 11),
#  ('Different Perspective', 7, 8),
#  ('Different Perspective', 8, 10),
#  ('Different Perspective', 9, 12),
#  ('Different Perspective', 10, 4),
#  ('Different Perspective', 11, 6),
#  ('Different Perspective', 12, 9),
#  ('Expression Game', 1, 6),
#  ('Expression Game', 2, 9),
#  ('Expression Game', 3, 12),
#  ('Expression Game', 4, 10),
#  ('Expression Game', 5, 9),
#  ('Expression Game', 6, 11),
#  ('Expression Game', 7, 12),
#  ('Expression Game', 8, 11),
#  ('Expression Game', 9, 17),
#  ('Expression Game', 10, 3),
#  ('Expression Game', 11, 11),
#  ('Expression Game', 12, 13),
#  ('Eye Contact Game', 1, 624),
#  ('Eye Contact Game', 2, 564),
#  ('Eye Contact Game', 3, 589),
#  ('Eye Contact Game', 4, 449),
#  ('Eye Contact Game', 5, 1408),
#  ('Eye Contact Game', 6, 1812),
#  ('Eye Contact Game', 7, 1194),
#  ('Eye Contact Game', 8, 1130),
#  ('Eye Contact Game', 9, 1674),
#  ('Eye Contact Game', 10, 3452),
#  ('Eye Contact Game', 11, 889),
#  ('Eye Contact Game', 12, 760),
#  ('Eye Contact Warm-up', 1, 707),
#  ('Eye Contact Warm-up', 2, 616),
#  ('Eye Contact Warm-up', 3, 616),
#  ('Eye Contact Warm-up', 4, 454),
#  ('Eye Contact Warm-up', 5, 1636),
#  ('Eye Contact Warm-up', 6, 2152),
#  ('Eye Contact Warm-up', 7, 1379),
#  ('Eye Contact Warm-up', 8, 1256),
#  ('Eye Contact Warm-up', 9, 1967),
#  ('Eye Contact Warm-up', 10, 3675),
#  ('Eye Contact Warm-up', 11, 941),
#  ('Eye Contact Warm-up', 12, 839),
#  ('Foot Pointing', 1, 506),
#  ('Foot Pointing', 2, 433),
#  ('Foot Pointing', 3, 477),
#  ('Foot Pointing', 4, 339),
#  ('Foot Pointing', 5, 926),
#  ('Foot Pointing', 6, 1125),
#  ('Foot Pointing', 7, 759),
#  ('Foot Pointing', 8, 653),
#  ('Foot Pointing', 9, 992),
#  ('Foot Pointing', 10, 2290),
#  ('Foot Pointing', 11, 685),
#  ('Foot Pointing', 12, 566),
#  ('Impossible Task Game', 1, 49),
#  ('Impossible Task Game', 2, 48),
#  ('Impossible Task Game', 3, 36),
#  ('Impossible Task Game', 4, 43),
#  ('Impossible Task Game', 5, 49),
#  ('Impossible Task Game', 6, 59),
#  ('Impossible Task Game', 7, 50),
#  ('Impossible Task Game', 8, 32),
#  ('Impossible Task Game', 9, 35),
#  ('Impossible Task Game', 10, 37),
#  ('Impossible Task Game', 11, 48),
#  ('Impossible Task Game', 12, 46),
#  ('Impossible Task Warm-up', 1, 51),
#  ('Impossible Task Warm-up', 2, 49),
#  ('Impossible Task Warm-up', 3, 37),
#  ('Impossible Task Warm-up', 4, 43),
#  ('Impossible Task Warm-up', 5, 49),
#  ('Impossible Task Warm-up', 6, 58),
#  ('Impossible Task Warm-up', 7, 51),
#  ('Impossible Task Warm-up', 8, 34),
#  ('Impossible Task Warm-up', 9, 36),
#  ('Impossible Task Warm-up', 10, 36),
#  ('Impossible Task Warm-up', 11, 49),
#  ('Impossible Task Warm-up', 12, 46),
#  ('Inferential Reasoning Game', 1, 410),
#  ('Inferential Reasoning Game', 2, 297),
#  ('Inferential Reasoning Game', 3, 335),
#  ('Inferential Reasoning Game', 4, 254),
#  ('Inferential Reasoning Game', 5, 533),
#  ('Inferential Reasoning Game', 6, 544),
#  ('Inferential Reasoning Game', 7, 432),
#  ('Inferential Reasoning Game', 8, 350),
#  ('Inferential Reasoning Game', 9, 398),
#  ('Inferential Reasoning Game', 10, 785),
#  ('Inferential Reasoning Game', 11, 362),
#  ('Inferential Reasoning Game', 12, 280),
#  ('Inferential Reasoning Warm-up', 1, 425),
#  ('Inferential Reasoning Warm-up', 2, 302),
#  ('Inferential Reasoning Warm-up', 3, 351),
#  ('Inferential Reasoning Warm-up', 4, 257),
#  ('Inferential Reasoning Warm-up', 5, 544),
#  ('Inferential Reasoning Warm-up', 6, 550),
#  ('Inferential Reasoning Warm-up', 7, 450),
#  ('Inferential Reasoning Warm-up', 8, 354),
#  ('Inferential Reasoning Warm-up', 9, 399),
#  ('Inferential Reasoning Warm-up', 10, 794),
#  ('Inferential Reasoning Warm-up', 11, 376),
#  ('Inferential Reasoning Warm-up', 12, 296),
#  ('Memory versus Pointing', 1, 464),
#  ('Memory versus Pointing', 2, 395),
#  ('Memory versus Pointing', 3, 381),
#  ('Memory versus Pointing', 4, 299),
#  ('Memory versus Pointing', 5, 711),
#  ('Memory versus Pointing', 6, 704),
#  ('Memory versus Pointing', 7, 511),
#  ('Memory versus Pointing', 8, 415),
#  ('Memory versus Pointing', 9, 574),
#  ('Memory versus Pointing', 10, 1218),
#  ('Memory versus Pointing', 11, 477),
#  ('Memory versus Pointing', 12, 376),
#  ('Memory versus Smell', 1, 465),
#  ('Memory versus Smell', 2, 374),
#  ('Memory versus Smell', 3, 382),
#  ('Memory versus Smell', 4, 280),
#  ('Memory versus Smell', 5, 667),
#  ('Memory versus Smell', 6, 666),
#  ('Memory versus Smell', 7, 491),
#  ('Memory versus Smell', 8, 402),
#  ('Memory versus Smell', 9, 529),
#  ('Memory versus Smell', 10, 1111),
#  ('Memory versus Smell', 11, 444),
#  ('Memory versus Smell', 12, 352),
#  ('Navigation Game', 1, 57),
#  ('Navigation Game', 2, 41),
#  ('Navigation Game', 3, 47),
#  ('Navigation Game', 4, 41),
#  ('Navigation Game', 5, 336),
#  ('Navigation Game', 6, 81),
#  ('Navigation Game', 7, 70),
#  ('Navigation Game', 8, 41),
#  ('Navigation Game', 9, 52),
#  ('Navigation Game', 10, 69),
#  ('Navigation Game', 11, 47),
#  ('Navigation Game', 12, 45),
#  ('Navigation Learning', 1, 59),
#  ('Navigation Learning', 2, 43),
#  ('Navigation Learning', 3, 47),
#  ('Navigation Learning', 4, 45),
#  ('Navigation Learning', 5, 444),
#  ('Navigation Learning', 6, 90),
#  ('Navigation Learning', 7, 74),
#  ('Navigation Learning', 8, 34),
#  ('Navigation Learning', 9, 54),
#  ('Navigation Learning', 10, 70),
#  ('Navigation Learning', 11, 47),
#  ('Navigation Learning', 12, 47),
#  ('Navigation Warm-up', 1, 62),
#  ('Navigation Warm-up', 2, 43),
#  ('Navigation Warm-up', 3, 50),
#  ('Navigation Warm-up', 4, 42),
#  ('Navigation Warm-up', 5, 625),
#  ('Navigation Warm-up', 6, 114),
#  ('Navigation Warm-up', 7, 88),
#  ('Navigation Warm-up', 8, 40),
#  ('Navigation Warm-up', 9, 58),
#  ('Navigation Warm-up', 10, 76),
#  ('Navigation Warm-up', 11, 52),
#  ('Navigation Warm-up', 12, 49),
#  ('Numerosity Warm-Up', 1, 36),
#  ('Numerosity Warm-Up', 2, 28),
#  ('Numerosity Warm-Up', 3, 35),
#  ('Numerosity Warm-Up', 4, 17),
#  ('Numerosity Warm-Up', 5, 37),
#  ('Numerosity Warm-Up', 6, 44),
#  ('Numerosity Warm-Up', 7, 37),
#  ('Numerosity Warm-Up', 8, 23),
#  ('Numerosity Warm-Up', 9, 24),
#  ('Numerosity Warm-Up', 10, 29),
#  ('Numerosity Warm-Up', 11, 26),
#  ('Numerosity Warm-Up', 12, 46),
#  ('One Cup Warm-up', 1, 476),
#  ('One Cup Warm-up', 2, 388),
#  ('One Cup Warm-up', 3, 388),
#  ('One Cup Warm-up', 4, 313),
#  ('One Cup Warm-up', 5, 757),
#  ('One Cup Warm-up', 6, 745),
#  ('One Cup Warm-up', 7, 536),
#  ('One Cup Warm-up', 8, 416),
#  ('One Cup Warm-up', 9, 602),
#  ('One Cup Warm-up', 10, 1272),
#  ('One Cup Warm-up', 11, 491),
#  ('One Cup Warm-up', 12, 401),
#  ('Physical Reasoning Game', 1, 317),
#  ('Physical Reasoning Game', 2, 252),
#  ('Physical Reasoning Game', 3, 321),
#  ('Physical Reasoning Game', 4, 224),
#  ('Physical Reasoning Game', 5, 430),
#  ('Physical Reasoning Game', 6, 424),
#  ('Physical Reasoning Game', 7, 360),
#  ('Physical Reasoning Game', 8, 316),
#  ('Physical Reasoning Game', 9, 309),
#  ('Physical Reasoning Game', 10, 711),
#  ('Physical Reasoning Game', 11, 341),
#  ('Physical Reasoning Game', 12, 250),
#  ('Physical Reasoning Warm-up', 1, 384),
#  ('Physical Reasoning Warm-up', 2, 290),
#  ('Physical Reasoning Warm-up', 3, 337),
#  ('Physical Reasoning Warm-up', 4, 247),
#  ('Physical Reasoning Warm-up', 5, 510),
#  ('Physical Reasoning Warm-up', 6, 504),
#  ('Physical Reasoning Warm-up', 7, 411),
#  ('Physical Reasoning Warm-up', 8, 347),
#  ('Physical Reasoning Warm-up', 9, 364),
#  ('Physical Reasoning Warm-up', 10, 742),
#  ('Physical Reasoning Warm-up', 11, 349),
#  ('Physical Reasoning Warm-up', 12, 276),
#  ('Self Control Game', 1, 8),
#  ('Self Control Game', 2, 8),
#  ('Self Control Game', 3, 11),
#  ('Self Control Game', 4, 9),
#  ('Self Control Game', 5, 9),
#  ('Self Control Game', 6, 11),
#  ('Self Control Game', 7, 14),
#  ('Self Control Game', 8, 13),
#  ('Self Control Game', 9, 19),
#  ('Self Control Game', 10, 9),
#  ('Self Control Game', 11, 15),
#  ('Self Control Game', 12, 6),
#  ('Shaker Game', 1, 2),
#  ('Shaker Game', 2, 9),
#  ('Shaker Game', 3, 8),
#  ('Shaker Game', 4, 4),
#  ('Shaker Game', 5, 10),
#  ('Shaker Game', 6, 7),
#  ('Shaker Game', 7, 5),
#  ('Shaker Game', 8, 6),
#  ('Shaker Game', 9, 12),
#  ('Shaker Game', 10, 10),
#  ('Shaker Game', 11, 3),
#  ('Shaker Game', 12, 1),
#  ('Shaker Warm-Up', 1, 2),
#  ('Shaker Warm-Up', 2, 11),
#  ('Shaker Warm-Up', 3, 8),
#  ('Shaker Warm-Up', 4, 4),
#  ('Shaker Warm-Up', 5, 10),
#  ('Shaker Warm-Up', 6, 7),
#  ('Shaker Warm-Up', 7, 5),
#  ('Shaker Warm-Up', 8, 6),
#  ('Shaker Warm-Up', 9, 13),
#  ('Shaker Warm-Up', 10, 11),
#  ('Shaker Warm-Up', 11, 3),
#  ('Shaker Warm-Up', 12, 1),
#  ('Shared Perspective', 1, 1),
#  ('Shared Perspective', 2, 3),
#  ('Shared Perspective', 3, 3),
#  ('Shared Perspective', 4, 8),
#  ('Shared Perspective', 5, 11),
#  ('Shared Perspective', 6, 11),
#  ('Shared Perspective', 7, 7),
#  ('Shared Perspective', 8, 10),
#  ('Shared Perspective', 9, 12),
#  ('Shared Perspective', 10, 4),
#  ('Shared Perspective', 11, 6),
#  ('Shared Perspective', 12, 7),
#  ('Slide', 1, 17),
#  ('Slide', 2, 12),
#  ('Slide', 3, 16),
#  ('Slide', 4, 11),
#  ('Slide', 5, 17),
#  ('Slide', 6, 10),
#  ('Slide', 7, 13),
#  ('Slide', 8, 6),
#  ('Slide', 9, 18),
#  ('Slide', 10, 7),
#  ('Slide', 11, 13),
#  ('Slide', 12, 7),
#  ('Smell Game', 1, 13),
#  ('Smell Game', 2, 18),
#  ('Smell Game', 3, 16),
#  ('Smell Game', 4, 6),
#  ('Smell Game', 5, 19),
#  ('Smell Game', 6, 9),
#  ('Smell Game', 7, 21),
#  ('Smell Game', 8, 10),
#  ('Smell Game', 9, 16),
#  ('Smell Game', 10, 15),
#  ('Smell Game', 11, 12),
#  ('Smell Game', 12, 13),
#  ('Stair Game', 1, 12),
#  ('Stair Game', 2, 8),
#  ('Stair Game', 3, 7),
#  ('Stair Game', 4, 4),
#  ('Stair Game', 5, 10),
#  ('Stair Game', 6, 7),
#  ('Stair Game', 7, 14),
#  ('Stair Game', 8, 15),
#  ('Stair Game', 9, 17),
#  ('Stair Game', 10, 7),
#  ('Stair Game', 11, 3),
#  ('Stair Game', 12, 8),
#  ('Switch', 1, 15),
#  ('Switch', 2, 12),
#  ('Switch', 3, 14),
#  ('Switch', 4, 11),
#  ('Switch', 5, 15),
#  ('Switch', 6, 11),
#  ('Switch', 7, 11),
#  ('Switch', 8, 10),
#  ('Switch', 9, 13),
#  ('Switch', 10, 9),
#  ('Switch', 11, 10),
#  ('Switch', 12, 6),
#  ('Treat Warm-up', 1, 626),
#  ('Treat Warm-up', 2, 495),
#  ('Treat Warm-up', 3, 515),
#  ('Treat Warm-up', 4, 393),
#  ('Treat Warm-up', 5, 1182),
#  ('Treat Warm-up', 6, 1444),
#  ('Treat Warm-up', 7, 951),
#  ('Treat Warm-up', 8, 791),
#  ('Treat Warm-up', 9, 1303),
#  ('Treat Warm-up', 10, 2626),
#  ('Treat Warm-up', 11, 744),
#  ('Treat Warm-up', 12, 667),
#  ('Turn Your Back', 1, 462),
#  ('Turn Your Back', 2, 372),
#  ('Turn Your Back', 3, 418),
#  ('Turn Your Back', 4, 298),
#  ('Turn Your Back', 5, 769),
#  ('Turn Your Back', 6, 778),
#  ('Turn Your Back', 7, 535),
#  ('Turn Your Back', 8, 418),
#  ('Turn Your Back', 9, 599),
#  ('Turn Your Back', 10, 1711),
#  ('Turn Your Back', 11, 601),
#  ('Turn Your Back', 12, 467),
#  ('Two Cup Warm-up', 1, 490),
#  ('Two Cup Warm-up', 2, 386),
#  ('Two Cup Warm-up', 3, 389),
#  ('Two Cup Warm-up', 4, 308),
#  ('Two Cup Warm-up', 5, 747),
#  ('Two Cup Warm-up', 6, 732),
#  ('Two Cup Warm-up', 7, 537),
#  ('Two Cup Warm-up', 8, 419),
#  ('Two Cup Warm-up', 9, 578),
#  ('Two Cup Warm-up', 10, 1234),
#  ('Two Cup Warm-up', 11, 482),
#  ('Two Cup Warm-up', 12, 379),
#  ('Warm-up', 1, 70),
#  ('Warm-up', 2, 77),
#  ('Warm-Up', 3, 79),
#  ('Warm-Up', 4, 54),
#  ('Warm-Up', 5, 71),
#  ('Warm-Up', 6, 64),
#  ('Warm-Up', 7, 101),
#  ('Warm-Up', 8, 64),
#  ('Warm-Up', 9, 103),
#  ('Warm-up', 10, 69),
#  ('Warm-Up', 11, 65),
#  ('Warm-up', 12, 56),
#  ('Watching', 1, 594),
#  ('Watching', 2, 443),
#  ('Watching', 3, 472),
#  ('Watching', 4, 322),
#  ('Watching', 5, 980),
#  ('Watching', 6, 1035),
#  ('Watching', 7, 679),
#  ('Watching', 8, 511),
#  ('Watching', 9, 809),
#  ('Watching', 10, 1797),
#  ('Watching', 11, 611),
#  ('Watching', 12, 555),
#  ('Watching - Part 2', 1, 445),
#  ('Watching - Part 2', 2, 372),
#  ('Watching - Part 2', 3, 406),
#  ('Watching - Part 2', 4, 282),
#  ('Watching - Part 2', 5, 734),
#  ('Watching - Part 2', 6, 747),
#  ('Watching - Part 2', 7, 504),
#  ('Watching - Part 2', 8, 405),
#  ('Watching - Part 2', 9, 568),
#  ('Watching - Part 2', 10, 1578),
#  ('Watching - Part 2', 11, 565),
#  ('Watching - Part 2', 12, 438),
#  ('Yawn Game', 1, 828),
#  ('Yawn Game', 2, 709),
#  ('Yawn Game', 3, 681),
#  ('Yawn Game', 4, 525),
#  ('Yawn Game', 5, 2065),
#  ('Yawn Game', 6, 2906),
#  ('Yawn Game', 7, 1775),
#  ('Yawn Game', 8, 1520),
#  ('Yawn Game', 9, 2563),
#  ('Yawn Game', 10, 4073),
#  ('Yawn Game', 11, 989),
#  ('Yawn Game', 12, 978),
#  ('Yawn Warm-up', 1, 834),
#  ('Yawn Warm-up', 2, 712),
#  ('Yawn Warm-up', 3, 698),
#  ('Yawn Warm-up', 4, 541),
#  ('Yawn Warm-up', 5, 2143),
#  ('Yawn Warm-up', 6, 3071),
#  ('Yawn Warm-up', 7, 1909),
#  ('Yawn Warm-up', 8, 1694),
#  ('Yawn Warm-up', 9, 2771),
#  ('Yawn Warm-up', 10, 4387),
#  ('Yawn Warm-up', 11, 1060),
#  ('Yawn Warm-up', 12, 1043)]

# %%
# %%sql
# SELECT test_name, MONTH(created_at) AS MONTH, COUNT(created_at) AS NUM_completed
# FROM complete_tests
# GROUP BY MONTH, test_name;
# Out:
# 480 rows affected.
# [('1 vs 1 Game', 1, 25),
#  ('3 vs 1 Game', 1, 35),
#  ('5 vs 1 Game', 1, 59),
#  ('Arm Pointing', 1, 622),
#  ('Cover Your Eyes', 1, 452),
#  ('Delayed Cup Game', 1, 356),
#  ('Different Perspective', 1, 2),
#  ('Expression Game', 1, 6),
#  ('Eye Contact Game', 1, 624),
#  ('Eye Contact Warm-up', 1, 707),
#  ('Foot Pointing', 1, 506),
#  ('Impossible Task Game', 1, 49),
#  ('Impossible Task Warm-up', 1, 51),
#  ('Inferential Reasoning Game', 1, 410),
#  ('Inferential Reasoning Warm-up', 1, 425),
#  ('Memory versus Pointing', 1, 464),
#  ('Memory versus Smell', 1, 465),
#  ('Navigation Game', 1, 57),
#  ('Navigation Learning', 1, 59),
#  ('Navigation Warm-up', 1, 62),
#  ('Numerosity Warm-Up', 1, 36),
#  ('One Cup Warm-up', 1, 476),
#  ('Physical Reasoning Game', 1, 317),
#  ('Physical Reasoning Warm-up', 1, 384),
#  ('Self Control Game', 1, 8),
#  ('Shaker Game', 1, 2),
#  ('Shaker Warm-Up', 1, 2),
#  ('Shared Perspective', 1, 1),
#  ('Slide', 1, 17),
#  ('Smell Game', 1, 13),
#  ('Stair Game', 1, 12),
#  ('Switch', 1, 15),
#  ('Treat Warm-up', 1, 626),
#  ('Turn Your Back', 1, 462),
#  ('Two Cup Warm-up', 1, 490),
#  ('Warm-up', 1, 70),
#  ('Watching', 1, 594),
#  ('Watching - Part 2', 1, 445),
#  ('Yawn Game', 1, 828),
#  ('Yawn Warm-up', 1, 834),
#  ('1 vs 1 Game', 2, 28),
#  ('3 vs 1 Game', 2, 28),
#  ('5 vs 1 Game', 2, 54),
#  ('Arm Pointing', 2, 498),
#  ('Cover Your Eyes', 2, 373),
#  ('Delayed Cup Game', 2, 319),
#  ('Different Perspective', 2, 3),
#  ('Expression Game', 2, 9),
#  ('Eye Contact Game', 2, 564),
#  ('Eye Contact Warm-up', 2, 616),
#  ('Foot Pointing', 2, 433),
#  ('Impossible Task Game', 2, 48),
#  ('Impossible Task Warm-up', 2, 49),
#  ('Inferential Reasoning Game', 2, 297),
#  ('Inferential Reasoning Warm-up', 2, 302),
#  ('Memory versus Pointing', 2, 395),
#  ('Memory versus Smell', 2, 374),
#  ('Navigation Game', 2, 41),
#  ('Navigation Learning', 2, 43),
#  ('Navigation Warm-up', 2, 43),
#  ('Numerosity Warm-Up', 2, 28),
#  ('One Cup Warm-up', 2, 388),
#  ('Physical Reasoning Game', 2, 252),
#  ('Physical Reasoning Warm-up', 2, 290),
#  ('Self Control Game', 2, 8),
#  ('Shaker Game', 2, 9),
#  ('Shaker Warm-Up', 2, 11),
#  ('Shared Perspective', 2, 3),
#  ('Slide', 2, 12),
#  ('Smell Game', 2, 18),
#  ('Stair Game', 2, 8),
#  ('Switch', 2, 12),
#  ('Treat Warm-up', 2, 495),
#  ('Turn Your Back', 2, 372),
#  ('Two Cup Warm-up', 2, 386),
#  ('Warm-up', 2, 77),
#  ('Watching', 2, 443),
#  ('Watching - Part 2', 2, 372),
#  ('Yawn Game', 2, 709),
#  ('Yawn Warm-up', 2, 712),
#  ('1 vs 1 Game', 3, 22),
#  ('3 vs 1 Game', 3, 34),
#  ('5 vs 1 Game', 3, 57),
#  ('Arm Pointing', 3, 507),
#  ('Cover Your Eyes', 3, 416),
#  ('Delayed Cup Game', 3, 350),
#  ('Different Perspective', 3, 4),
#  ('Expression Game', 3, 12),
#  ('Eye Contact Game', 3, 589),
#  ('Eye Contact Warm-up', 3, 616),
#  ('Foot Pointing', 3, 477),
#  ('Impossible Task Game', 3, 36),
#  ('Impossible Task Warm-up', 3, 37),
#  ('Inferential Reasoning Game', 3, 335),
#  ('Inferential Reasoning Warm-up', 3, 351),
#  ('Memory versus Pointing', 3, 381),
#  ('Memory versus Smell', 3, 382),
#  ('Navigation Game', 3, 47),
#  ('Navigation Learning', 3, 47),
#  ('Navigation Warm-up', 3, 50),
#  ('Numerosity Warm-Up', 3, 35),
#  ('One Cup Warm-up', 3, 388),
#  ('Physical Reasoning Game', 3, 321),
#  ('Physical Reasoning Warm-up', 3, 337),
#  ('Self Control Game', 3, 11),
#  ('Shaker Game', 3, 8),
#  ('Shaker Warm-Up', 3, 8),
#  ('Shared Perspective', 3, 3),
#  ('Slide', 3, 16),
#  ('Smell Game', 3, 16),
#  ('Stair Game', 3, 7),
#  ('Switch', 3, 14),
#  ('Treat Warm-up', 3, 515),
#  ('Turn Your Back', 3, 418),
#  ('Two Cup Warm-up', 3, 389),
#  ('Warm-Up', 3, 79),
#  ('Watching', 3, 472),
#  ('Watching - Part 2', 3, 406),
#  ('Yawn Game', 3, 681),
#  ('Yawn Warm-up', 3, 698),
#  ('1 vs 1 Game', 4, 12),
#  ('3 vs 1 Game', 4, 16),
#  ('5 vs 1 Game', 4, 29),
#  ('Arm Pointing', 4, 381),
#  ('Cover Your Eyes', 4, 291),
#  ('Delayed Cup Game', 4, 256),
#  ('Different Perspective', 4, 8),
#  ('Expression Game', 4, 10),
#  ('Eye Contact Game', 4, 449),
#  ('Eye Contact Warm-up', 4, 454),
#  ('Foot Pointing', 4, 339),
#  ('Impossible Task Game', 4, 43),
#  ('Impossible Task Warm-up', 4, 43),
#  ('Inferential Reasoning Game', 4, 254),
#  ('Inferential Reasoning Warm-up', 4, 257),
#  ('Memory versus Pointing', 4, 299),
#  ('Memory versus Smell', 4, 280),
#  ('Navigation Game', 4, 41),
#  ('Navigation Learning', 4, 45),
#  ('Navigation Warm-up', 4, 42),
#  ('Numerosity Warm-Up', 4, 17),
#  ('One Cup Warm-up', 4, 313),
#  ('Physical Reasoning Game', 4, 224),
#  ('Physical Reasoning Warm-up', 4, 247),
#  ('Self Control Game', 4, 9),
#  ('Shaker Game', 4, 4),
#  ('Shaker Warm-Up', 4, 4),
#  ('Shared Perspective', 4, 8),
#  ('Slide', 4, 11),
#  ('Smell Game', 4, 6),
#  ('Stair Game', 4, 4),
#  ('Switch', 4, 11),
#  ('Treat Warm-up', 4, 393),
#  ('Turn Your Back', 4, 298),
#  ('Two Cup Warm-up', 4, 308),
#  ('Warm-Up', 4, 54),
#  ('Watching', 4, 322),
#  ('Watching - Part 2', 4, 282),
#  ('Yawn Game', 4, 525),
#  ('Yawn Warm-up', 4, 541),
#  ('1 vs 1 Game', 5, 13),
#  ('3 vs 1 Game', 5, 34),
#  ('5 vs 1 Game', 5, 50),
#  ('Arm Pointing', 5, 1149),
#  ('Cover Your Eyes', 5, 753),
#  ('Delayed Cup Game', 5, 539),
#  ('Different Perspective', 5, 12),
#  ('Expression Game', 5, 9),
#  ('Eye Contact Game', 5, 1408),
#  ('Eye Contact Warm-up', 5, 1636),
#  ('Foot Pointing', 5, 926),
#  ('Impossible Task Game', 5, 49),
#  ('Impossible Task Warm-up', 5, 49),
#  ('Inferential Reasoning Game', 5, 533),
#  ('Inferential Reasoning Warm-up', 5, 544),
#  ('Memory versus Pointing', 5, 711),
#  ('Memory versus Smell', 5, 667),
#  ('Navigation Game', 5, 336),
#  ('Navigation Learning', 5, 444),
#  ('Navigation Warm-up', 5, 625),
#  ('Numerosity Warm-Up', 5, 37),
#  ('One Cup Warm-up', 5, 757),
#  ('Physical Reasoning Game', 5, 430),
#  ('Physical Reasoning Warm-up', 5, 510),
#  ('Self Control Game', 5, 9),
#  ('Shaker Game', 5, 10),
#  ('Shaker Warm-Up', 5, 10),
#  ('Shared Perspective', 5, 11),
#  ('Slide', 5, 17),
#  ('Smell Game', 5, 19),
#  ('Stair Game', 5, 10),
#  ('Switch', 5, 15),
#  ('Treat Warm-up', 5, 1182),
#  ('Turn Your Back', 5, 769),
#  ('Two Cup Warm-up', 5, 747),
#  ('Warm-Up', 5, 71),
#  ('Watching', 5, 980),
#  ('Watching - Part 2', 5, 734),
#  ('Yawn Game', 5, 2065),
#  ('Yawn Warm-up', 5, 2143),
#  ('1 vs 1 Game', 6, 18),
#  ('3 vs 1 Game', 6, 42),
#  ('5 vs 1 Game', 6, 61),
#  ('Arm Pointing', 6, 1424),
#  ('Cover Your Eyes', 6, 767),
#  ('Delayed Cup Game', 6, 525),
#  ('Different Perspective', 6, 11),
#  ('Expression Game', 6, 11),
#  ('Eye Contact Game', 6, 1812),
#  ('Eye Contact Warm-up', 6, 2152),
#  ('Foot Pointing', 6, 1125),
#  ('Impossible Task Game', 6, 59),
#  ('Impossible Task Warm-up', 6, 58),
#  ('Inferential Reasoning Game', 6, 544),
#  ('Inferential Reasoning Warm-up', 6, 550),
#  ('Memory versus Pointing', 6, 704),
#  ('Memory versus Smell', 6, 666),
#  ('Navigation Game', 6, 81),
#  ('Navigation Learning', 6, 90),
#  ('Navigation Warm-up', 6, 114),
#  ('Numerosity Warm-Up', 6, 44),
#  ('One Cup Warm-up', 6, 745),
#  ('Physical Reasoning Game', 6, 424),
#  ('Physical Reasoning Warm-up', 6, 504),
#  ('Self Control Game', 6, 11),
#  ('Shaker Game', 6, 7),
#  ('Shaker Warm-Up', 6, 7),
#  ('Shared Perspective', 6, 11),
#  ('Slide', 6, 10),
#  ('Smell Game', 6, 9),
#  ('Stair Game', 6, 7),
#  ('Switch', 6, 11),
#  ('Treat Warm-up', 6, 1444),
#  ('Turn Your Back', 6, 778),
#  ('Two Cup Warm-up', 6, 732),
#  ('Warm-Up', 6, 64),
#  ('Watching', 6, 1035),
#  ('Watching - Part 2', 6, 747),
#  ('Yawn Game', 6, 2906),
#  ('Yawn Warm-up', 6, 3071),
#  ('1 vs 1 Game', 7, 36),
#  ('3 vs 1 Game', 7, 37),
#  ('5 vs 1 Game', 7, 69),
#  ('Arm Pointing', 7, 913),
#  ('Cover Your Eyes', 7, 521),
#  ('Delayed Cup Game', 7, 407),
#  ('Different Perspective', 7, 8),
#  ('Expression Game', 7, 12),
#  ('Eye Contact Game', 7, 1194),
#  ('Eye Contact Warm-up', 7, 1379),
#  ('Foot Pointing', 7, 759),
#  ('Impossible Task Game', 7, 50),
#  ('Impossible Task Warm-up', 7, 51),
#  ('Inferential Reasoning Game', 7, 432),
#  ('Inferential Reasoning Warm-up', 7, 450),
#  ('Memory versus Pointing', 7, 511),
#  ('Memory versus Smell', 7, 491),
#  ('Navigation Game', 7, 70),
#  ('Navigation Learning', 7, 74),
#  ('Navigation Warm-up', 7, 88),
#  ('Numerosity Warm-Up', 7, 37),
#  ('One Cup Warm-up', 7, 536),
#  ('Physical Reasoning Game', 7, 360),
#  ('Physical Reasoning Warm-up', 7, 411),
#  ('Self Control Game', 7, 14),
#  ('Shaker Game', 7, 5),
#  ('Shaker Warm-Up', 7, 5),
#  ('Shared Perspective', 7, 7),
#  ('Slide', 7, 13),
#  ('Smell Game', 7, 21),
#  ('Stair Game', 7, 14),
#  ('Switch', 7, 11),
#  ('Treat Warm-up', 7, 951),
#  ('Turn Your Back', 7, 535),
#  ('Two Cup Warm-up', 7, 537),
#  ('Warm-Up', 7, 101),
#  ('Watching', 7, 679),
#  ('Watching - Part 2', 7, 504),
#  ('Yawn Game', 7, 1775),
#  ('Yawn Warm-up', 7, 1909),
#  ('1 vs 1 Game', 8, 17),
#  ('3 vs 1 Game', 8, 23),
#  ('5 vs 1 Game', 8, 38),
#  ('Arm Pointing', 8, 779),
#  ('Cover Your Eyes', 8, 408),
#  ('Delayed Cup Game', 8, 355),
#  ('Different Perspective', 8, 10),
#  ('Expression Game', 8, 11),
#  ('Eye Contact Game', 8, 1130),
#  ('Eye Contact Warm-up', 8, 1256),
#  ('Foot Pointing', 8, 653),
#  ('Impossible Task Game', 8, 32),
#  ('Impossible Task Warm-up', 8, 34),
#  ('Inferential Reasoning Game', 8, 350),
#  ('Inferential Reasoning Warm-up', 8, 354),
#  ('Memory versus Pointing', 8, 415),
#  ('Memory versus Smell', 8, 402),
#  ('Navigation Game', 8, 41),
#  ('Navigation Learning', 8, 34),
#  ('Navigation Warm-up', 8, 40),
#  ('Numerosity Warm-Up', 8, 23),
#  ('One Cup Warm-up', 8, 416),
#  ('Physical Reasoning Game', 8, 316),
#  ('Physical Reasoning Warm-up', 8, 347),
#  ('Self Control Game', 8, 13),
#  ('Shaker Game', 8, 6),
#  ('Shaker Warm-Up', 8, 6),
#  ('Shared Perspective', 8, 10),
#  ('Slide', 8, 6),
#  ('Smell Game', 8, 10),
#  ('Stair Game', 8, 15),
#  ('Switch', 8, 10),
#  ('Treat Warm-up', 8, 791),
#  ('Turn Your Back', 8, 418),
#  ('Two Cup Warm-up', 8, 419),
#  ('Warm-Up', 8, 64),
#  ('Watching', 8, 511),
#  ('Watching - Part 2', 8, 405),
#  ('Yawn Game', 8, 1520),
#  ('Yawn Warm-up', 8, 1694),
#  ('1 vs 1 Game', 9, 28),
#  ('3 vs 1 Game', 9, 24),
#  ('5 vs 1 Game', 9, 50),
#  ('Arm Pointing', 9, 1243),
#  ('Cover Your Eyes', 9, 574),
#  ('Delayed Cup Game', 9, 424),
#  ('Different Perspective', 9, 12),
#  ('Expression Game', 9, 17),
#  ('Eye Contact Game', 9, 1674),
#  ('Eye Contact Warm-up', 9, 1967),
#  ('Foot Pointing', 9, 992),
#  ('Impossible Task Game', 9, 35),
#  ('Impossible Task Warm-up', 9, 36),
#  ('Inferential Reasoning Game', 9, 398),
#  ('Inferential Reasoning Warm-up', 9, 399),
#  ('Memory versus Pointing', 9, 574),
#  ('Memory versus Smell', 9, 529),
#  ('Navigation Game', 9, 52),
#  ('Navigation Learning', 9, 54),
#  ('Navigation Warm-up', 9, 58),
#  ('Numerosity Warm-Up', 9, 24),
#  ('One Cup Warm-up', 9, 602),
#  ('Physical Reasoning Game', 9, 309),
#  ('Physical Reasoning Warm-up', 9, 364),
#  ('Self Control Game', 9, 19),
#  ('Shaker Game', 9, 12),
#  ('Shaker Warm-Up', 9, 13),
#  ('Shared Perspective', 9, 12),
#  ('Slide', 9, 18),
#  ('Smell Game', 9, 16),
#  ('Stair Game', 9, 17),
#  ('Switch', 9, 13),
#  ('Treat Warm-up', 9, 1303),
#  ('Turn Your Back', 9, 599),
#  ('Two Cup Warm-up', 9, 578),
#  ('Warm-Up', 9, 103),
#  ('Watching', 9, 809),
#  ('Watching - Part 2', 9, 568),
#  ('Yawn Game', 9, 2563),
#  ('Yawn Warm-up', 9, 2771),
#  ('1 vs 1 Game', 10, 27),
#  ('3 vs 1 Game', 10, 28),
#  ('5 vs 1 Game', 10, 54),
#  ('Arm Pointing', 10, 2535),
#  ('Cover Your Eyes', 10, 1653),
#  ('Delayed Cup Game', 10, 1019),
#  ('Different Perspective', 10, 4),
#  ('Expression Game', 10, 3),
#  ('Eye Contact Game', 10, 3452),
#  ('Eye Contact Warm-up', 10, 3675),
#  ('Foot Pointing', 10, 2290),
#  ('Impossible Task Game', 10, 37),
#  ('Impossible Task Warm-up', 10, 36),
#  ('Inferential Reasoning Game', 10, 785),
#  ('Inferential Reasoning Warm-up', 10, 794),
#  ('Memory versus Pointing', 10, 1218),
#  ('Memory versus Smell', 10, 1111),
#  ('Navigation Game', 10, 69),
#  ('Navigation Learning', 10, 70),
#  ('Navigation Warm-up', 10, 76),
#  ('Numerosity Warm-Up', 10, 29),
#  ('One Cup Warm-up', 10, 1272),
#  ('Physical Reasoning Game', 10, 711),
#  ('Physical Reasoning Warm-up', 10, 742),
#  ('Self Control Game', 10, 9),
#  ('Shaker Game', 10, 10),
#  ('Shaker Warm-Up', 10, 11),
#  ('Shared Perspective', 10, 4),
#  ('Slide', 10, 7),
#  ('Smell Game', 10, 15),
#  ('Stair Game', 10, 7),
#  ('Switch', 10, 9),
#  ('Treat Warm-up', 10, 2626),
#  ('Turn Your Back', 10, 1711),
#  ('Two Cup Warm-up', 10, 1234),
#  ('Warm-up', 10, 69),
#  ('Watching', 10, 1797),
#  ('Watching - Part 2', 10, 1578),
#  ('Yawn Game', 10, 4073),
#  ('Yawn Warm-up', 10, 4387),
#  ('1 vs 1 Game', 11, 15),
#  ('3 vs 1 Game', 11, 22),
#  ('5 vs 1 Game', 11, 40),
#  ('Arm Pointing', 11, 735),
#  ('Cover Your Eyes', 11, 595),
#  ('Delayed Cup Game', 11, 422),
#  ('Different Perspective', 11, 6),
#  ('Expression Game', 11, 11),
#  ('Eye Contact Game', 11, 889),
#  ('Eye Contact Warm-up', 11, 941),
#  ('Foot Pointing', 11, 685),
#  ('Impossible Task Game', 11, 48),
#  ('Impossible Task Warm-up', 11, 49),
#  ('Inferential Reasoning Game', 11, 362),
#  ('Inferential Reasoning Warm-up', 11, 376),
#  ('Memory versus Pointing', 11, 477),
#  ('Memory versus Smell', 11, 444),
#  ('Navigation Game', 11, 47),
#  ('Navigation Learning', 11, 47),
#  ('Navigation Warm-up', 11, 52),
#  ('Numerosity Warm-Up', 11, 26),
#  ('One Cup Warm-up', 11, 491),
#  ('Physical Reasoning Game', 11, 341),
#  ('Physical Reasoning Warm-up', 11, 349),
#  ('Self Control Game', 11, 15),
#  ('Shaker Game', 11, 3),
#  ('Shaker Warm-Up', 11, 3),
#  ('Shared Perspective', 11, 6),
#  ('Slide', 11, 13),
#  ('Smell Game', 11, 12),
#  ('Stair Game', 11, 3),
#  ('Switch', 11, 10),
#  ('Treat Warm-up', 11, 744),
#  ('Turn Your Back', 11, 601),
#  ('Two Cup Warm-up', 11, 482),
#  ('Warm-Up', 11, 65),
#  ('Watching', 11, 611),
#  ('Watching - Part 2', 11, 565),
#  ('Yawn Game', 11, 989),
#  ('Yawn Warm-up', 11, 1060),
#  ('1 vs 1 Game', 12, 14),
#  ('3 vs 1 Game', 12, 45),
#  ('5 vs 1 Game', 12, 59),
#  ('Arm Pointing', 12, 666),
#  ('Cover Your Eyes', 12, 447),
#  ('Delayed Cup Game', 12, 299),
#  ('Different Perspective', 12, 9),
#  ('Expression Game', 12, 13),
#  ('Eye Contact Game', 12, 760),
#  ('Eye Contact Warm-up', 12, 839),
#  ('Foot Pointing', 12, 566),
#  ('Impossible Task Game', 12, 46),
#  ('Impossible Task Warm-up', 12, 46),
#  ('Inferential Reasoning Game', 12, 280),
#  ('Inferential Reasoning Warm-up', 12, 296),
#  ('Memory versus Pointing', 12, 376),
#  ('Memory versus Smell', 12, 352),
#  ('Navigation Game', 12, 45),
#  ('Navigation Learning', 12, 47),
#  ('Navigation Warm-up', 12, 49),
#  ('Numerosity Warm-Up', 12, 46),
#  ('One Cup Warm-up', 12, 401),
#  ('Physical Reasoning Game', 12, 250),
#  ('Physical Reasoning Warm-up', 12, 276),
#  ('Self Control Game', 12, 6),
#  ('Shaker Game', 12, 1),
#  ('Shaker Warm-Up', 12, 1),
#  ('Shared Perspective', 12, 7),
#  ('Slide', 12, 7),
#  ('Smell Game', 12, 13),
#  ('Stair Game', 12, 8),
#  ('Switch', 12, 6),
#  ('Treat Warm-up', 12, 667),
#  ('Turn Your Back', 12, 467),
#  ('Two Cup Warm-up', 12, 379),
#  ('Warm-up', 12, 56),
#  ('Watching', 12, 555),
#  ('Watching - Part 2', 12, 438),
#  ('Yawn Game', 12, 978),
#  ('Yawn Warm-up', 12, 1043)]

# %% [markdown]
# Notice that in the first case, the first block of rows share the same test_name, but are broken up into separate months (for those of you who took the "Data Visualization and Communication with Tableau" course of this specialization, this is similar to what would happen if you put test_name first and created_at second on the rows or columns shelf in Tableau).
#
# In the second case, the first block of rows share the same month, but are broken up into separate tests  (this is similar to what would happen if you put created_at first and test_name second on the rows or columns shelf in Tableau).  If you were to visualize these outputs, they would look like the charts below.
#
# <img src="https://duke.box.com/shared/static/y6l3ldxg289brid5mmn886qweglt65qv.jpg" width=800 alt="ORDER" />
#
# Different database servers might default to ordering the outputs in a certain way, but you shouldn't rely on that being the case.  To ensure the output is ordered in a way you intend, add an ORDER BY clause to your grouped query using the syntax you already know and have practiced:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, Month
# ORDER BY test_name ASC, Month ASC;
# ```
#
# **Question 1: Output a table that calculates the number of distinct female and male dogs in each breed group of the Dogs table, sorted by the total number of dogs in descending order (the sex/breed_group pair with the greatest number of dogs should have 8466 unique Dog_Guids):**

# %%
# %%sql
# SELECT breed_group, gender,COUNT(*) AS countA
# FROM dogs
# GROUP BY 2, 1
# ORDER BY 3 DESC
# Out:
# 18 rows affected.
# [(None, 'male', 8466),
#  (None, 'female', 8367),
#  ('Sporting', 'male', 2584),
#  ('Sporting', 'female', 2262),
#  ('Herding', 'male', 1736),
#  ('Herding', 'female', 1704),
#  ('Toy', 'male', 1473),
#  ('Toy', 'female', 1145),
#  ('Non-Sporting', 'male', 1098),
#  ('Working', 'male', 1075),
#  ('Non-Sporting', 'female', 919),
#  ('Terrier', 'male', 919),
#  ('Working', 'female', 895),
#  ('Terrier', 'female', 794),
#  ('Hound', 'male', 725),
#  ('Hound', 'female', 614),
#  ('', 'male', 147),
#  ('', 'female', 127)]

# %% [markdown]
# Some database servers, including MySQL, allow you to use numbers in place of field names in the GROUP BY or ORDER BY fields to reduce the overall length of the queries.  I tend to avoid this abbreviated method of writing queries because I find it challenging to troubleshoot when you are writing complicated queries with many fields, but it does allow you to write queries faster.  To use this method, assign each field in your SELECT statement a number acording to the order the field appears in the SELECT statement.  In the following statement:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# ```
#
# test_name would be #1, Month would be #2, and Num_Completed_Tests would be #3.  You could then rewrite the query above to read:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY 1, 2
# ORDER BY 1 ASC, 2 ASC;
# ```
#
# **Question 2: Revise the query your wrote in Question 1 so that it uses only numbers in the GROUP BY and ORDER BY fields.**

# %%
# %%sql
# SELECT breed_group, gender,COUNT(*) AS countA
# FROM dogs
# GROUP BY gender, breed_group
# ORDER BY countA DESC
# Out:
# 18 rows affected.
# [(None, 'male', 8466),
#  (None, 'female', 8367),
#  ('Sporting', 'male', 2584),
#  ('Sporting', 'female', 2262),
#  ('Herding', 'male', 1736),
#  ('Herding', 'female', 1704),
#  ('Toy', 'male', 1473),
#  ('Toy', 'female', 1145),
#  ('Non-Sporting', 'male', 1098),
#  ('Working', 'male', 1075),
#  ('Non-Sporting', 'female', 919),
#  ('Terrier', 'male', 919),
#  ('Working', 'female', 895),
#  ('Terrier', 'female', 794),
#  ('Hound', 'male', 725),
#  ('Hound', 'female', 614),
#  ('', 'male', 147),
#  ('', 'female', 127)]

# %% [markdown]
# ## The HAVING clause
#
# Just like you can query subsets of rows using the WHERE clause, you can query subsets of aggregated groups using the HAVING clause.  However, wheras the expression that follows a WHERE clause has to be applicable to each row of data in a column, the expression that follows a HAVING clause has to be applicable or computable using a group of data.
#
# If you wanted to examine the number of tests completed only during the winter holiday months of November and December, you would need to use a WHERE clause, because the month a test was completed in is recorded in each row.  Your query might look like this:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# WHERE MONTH(created_at)=11 OR MONTH(created_at)=12
# GROUP BY 1, 2
# ORDER BY 3 DESC;
# ```
# If you then wanted to output only the test-month pairs that had at least 20 records in them, you would add a HAVING clause, because the stipulation of at least 20 records only makes sense and is only computable at the aggregated group level:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# WHERE MONTH(created_at)=11 OR MONTH(created_at)=12
# GROUP BY 1, 2
# HAVING COUNT(created_at)>=20
# ORDER BY 3 DESC;
# ```
#
# **Question 3: Revise the query your wrote in Question 2 so that it (1) excludes the NULL and empty string entries in the breed_group field, and (2) excludes any groups that don't have at least 1,000 distinct Dog_Guids in them.  Your result should contain 8 rows.  (HINT: sometimes empty strings are registered as non-NULL values.  You might want to include the following line somewhere in your query to exclude these values as well):**
#
# ```mySQL
# breed_group!=""
# ```

# %%
# %%sql
# SELECT breed_group, gender,COUNT(*) AS countA
# FROM dogs
# WHERE breed_group IS NOT NULL AND breed_group<>''
# GROUP BY breed_group, gender
# HAVING COUNT(gender)>1000
# ORDER BY countA DESC
# Out:
# 8 rows affected.
# [('Sporting', 'male', 2584),
#  ('Sporting', 'female', 2262),
#  ('Herding', 'male', 1736),
#  ('Herding', 'female', 1704),
#  ('Toy', 'male', 1473),
#  ('Toy', 'female', 1145),
#  ('Non-Sporting', 'male', 1098),
#  ('Working', 'male', 1075)]

# %% [markdown]
# We will review several issues that can be tricky about using GROUP BY in your queries in the next lesson, but those issues will make more sense once you are sure you are comfortable with the basic functionality of the GROUP BY and HAVING clauses.
#
#
#
# ## Practice incorporating GROUP BY and HAVING into your own queries.
#
# **Question 4: Write a query that outputs the average number of tests completed and average mean inter-test-interval for every breed type, sorted by the average number of completed tests in descending order (popular hybrid should be the first row in your output).**

# %%
# %%sql
# SELECT breed,AVG(total_tests_completed), AVG(time_diff_between_first_and_last_game_minutes)
# FROM dogs
# GROUP BY breed
# ORDER BY 2 DESC;
# Out:
# 2006 rows affected.
# [('Golden Retriever-Brittany Mix', 43.0, 491204.43333),
#  ('Golden Retriever-Airedale Terrier Mix', 42.0, 370750.26667),
#  ('Rhodesian Ridgeback-American Staffordshire Terrier Mix', 40.5, 364345.658335),
#  ('Siberian Husky-German Shorthaired Pointer Mix', 35.0, 715842.5),
#  ('Portuguese Pointer', 34.0, 435153.38333),
#  ('German Shepherd Dog-Gordon Setter Mix', 32.0, 249587.91667),
#  ('Danish-Swedish Farmdog-Czechoslovakian Vlcak Mix', 31.0, 26071.65),
#  ('Australian Shepherd-Bloodhound Mix', 31.0, 168790.45),
#  ('-Collie Mix', 30.0, 120638.51667),
#  ('German Shepherd Dog-American Eskimo Dog Mix', 30.0, 193806.70000004699),
#  ('Schapendoes', 30.0, 517018.36667),
#  ('American Staffordshire Terrier-Australian Shepherd Mix', 28.0, 154115.3),
#  ('Tosa', 28.0, 144445.08333),
#  ('Russell Terrier-Japanese Chin Mix', 28.0, 164349.16667),
#  ('Chihuahua-American Staffordshire Terrier Mix', 27.0, 293822.76667),
#  ('Border Collie-Great Dane Mix', 26.5, 158443.9),
#  ('Australian Cattle Dog-Curly-Coated Retriever Mix', 26.0, 109417.01667),
#  ('American Eskimo Dog-Papillon Mix', 25.0, 97860.666667),
#  ('Boston Terrier-Pug Mix', 25.0, 14423.95),
#  ('American Pit Bull Terrier-Bull Terrier Mix', 25.0, 553015.01667),
#  ('Cardigan Welsh Corgi-Beagle Mix', 25.0, 42194.15),
#  ('Polish Lowland Sheepdog', 23.5, 288482.8208325),
#  ('Ibizan Hound', 23.5, 373630.01666829997),
#  ('American Pit Bull Terrier- Mix', 23.5, 451400.75),
#  ('Basenji-Manchester Terrier Mix', 23.0, 16171.633333),
#  ('American Pit Bull Terrier-Australian Shepherd Mix', 23.0, 109398.7),
#  ('Golden Retriever-St. Bernard Mix', 23.0, 132877.96667),
#  ('Belgian Malinois-Chinese Shar-Pei Mix', 23.0, 373219.15),
#  ('American Eskimo Dog-Staffordshire Bull Terrier Mix', 23.0, 40491.533333),
#  ('Border Collie-Whippet Mix', 22.5, 31236.225),
#  ('Labrador Retriever-Basenji Mix', 22.0, 240274.61667),
#  ('Brittany-Poodle Mix', 22.0, 267889.78333),
#  ('Boston Terrier-Bulldog Mix', 22.0, 414793.56667),
#  ('Catahoula Leopard Dog-Rottweiler Mix', 22.0, 46953.083333),
#  ('Greyhound-Pointer Mix', 22.0, 487256.76667),
#  ('Bluetick Coonhound', 21.0, 162499.77222393235),
#  ('English Cocker Spaniel-Cocker Spaniel Mix', 20.0, 17461.05),
#  ('Beagle-Cavalier King Charles Spaniel Mix', 20.0, 22948.0),
#  ('Canaan Dog- Mix', 20.0, 69088.983333),
#  ('Labrador Retriever-Cane Corso Mix', 20.0, 497.73333343),
#  ('Pembroke Welsh Corgi-Russell Terrier Mix', 20.0, 181540.36667),
#  ('Labrador Retriever-Cardigan Welsh Corgi Mix', 20.0, 135.01666658),
#  ('Pug-Maltese Mix', 20.0, 33210.8),
#  ('Alaskan Malamute-Collie Mix', 20.0, 9783.8999999),
#  ('Beagle- Mix', 20.0, 13615.883333),
#  ('Bearded Collie-Beagle Mix', 20.0, 334894.1),
#  ('Dogue de Bordeaux-Boxer Mix', 20.0, 20180.266667),
#  ('-German Shepherd Dog Mix', 20.0, 264543.33333),
#  ('Afghan Hound-Golden Retriever Mix', 20.0, 11940.6),
#  ('Brittany-German Shorthaired Pointer Mix', 20.0, 11840.55),
#  ('American Eskimo Dog-Russell Terrier Mix', 20.0, 577376.26667),
#  ('Pekingese-Parson Russell Terrier Mix', 20.0, 388.26666674),
#  ('Dachshund-Boston Terrier Mix', 20.0, 1746.8499999),
#  ('Redbone Coonhound-Bloodhound Mix', 20.0, 175.36666665),
#  ('Chinese Shar-Pei-Labrador Retriever Mix', 20.0, 13159.816667),
#  ('Pomeranian-Basenji Mix', 20.0, 1610.3333335),
#  ('Portuguese Podengo Pequeno', 20.0, 5411.9500001),
#  ('Australian Shepherd-Shih Tzu Mix', 20.0, 6401.4500001),
#  ('American Pit Bull Terrier-Boston Terrier Mix', 20.0, 2596.9833334),
#  ('Doberman Pinscher-Greyhound Mix', 20.0, 173555.03333),
#  ('Redbone Coonhound-Rhodesian Ridgeback Mix', 20.0, 2114.3000001),
#  ('Catahoula Leopard Dog-Plott Mix', 20.0, 2149.0),
#  ('Poodle-Japanese Chin Mix', 20.0, 330735.08333),
#  ('Great Pyrenees-Siberian Husky Mix', 20.0, 1024956.0833),
#  ('Dachshund-Pomeranian Mix', 20.0, 401492.71667),
#  ('Poodle-Pomeranian Mix', 20.0, 6795.0500001),
#  ('Portuguese Podengo', 20.0, 18141.933333),
#  ('Labrador Retriever-Flat-Coated Retriever Mix', 20.0, 2367.5166668),
#  ('Belgian Tervuren-Whippet Mix', 20.0, 7230.6500001),
#  ('Dogue de Bordeaux-Labrador Retriever Mix', 20.0, 1244.6500001),
#  ('Weimaraner-Bluetick Coonhound Mix', 20.0, 135623.33333),
#  ('Jindo-German Shepherd Dog Mix', 20.0, 6296.8833333),
#  ('Dalmatian-American Pit Bull Terrier Mix', 20.0, 43416.366667),
#  ('Pug-French Bulldog Mix', 20.0, 40832.416667),
#  ('Bull Terrier-Staffordshire Bull Terrier Mix', 20.0, 146.61666669),
#  ('Basset Hound-Beagle Mix', 20.0, 210056.1),
#  ('Perro de Presa Canario', 20.0, 5768.35),
#  ('Boxer-Siberian Husky Mix', 20.0, 4329.5833333),
#  ('Irish Wolfhound-Great Dane Mix', 20.0, 28762.533333),
#  ('Border Collie-Boxer Mix', 20.0, 12600.2),
#  ('Irish Setter-Poodle Mix', 20.0, 55392.858333),
#  ('Bullmastiff-Chinese Shar-Pei Mix', 20.0, 4650.3500001),
#  ('Greyhound-Saluki Mix', 20.0, 1494.1166667),
#  ('Greyhound-Scottish Deerhound Mix', 20.0, 168516.35),
#  ('Bernese Mountain Dog-Border Collie Mix', 20.0, 24495.766667),
#  ('Border Collie-Belgian Sheepdog Mix', 20.0, 179.96666668),
#  ('American Eskimo Dog-Australian Shepherd Mix', 20.0, 8594.4666667),
#  ('German Shepherd Dog-Shiba Inu Mix', 20.0, 7351.2666666),
#  ('Beagle-Chow Chow Mix', 20.0, 90691.05),
#  ('Beagle-Smooth Fox Terrier Mix', 20.0, 113951.06667),
#  ('Airedale Terrier-German Shorthaired Pointer Mix', 20.0, 7354.6333333),
#  ('Miniature Schnauzer-Shih Tzu Mix', 20.0, 6194.0666666),
#  ('Rottweiler-Border Collie Mix', 20.0, 105146.66667),
#  ('English Setter-Border Collie Mix', 20.0, 761568.83333),
#  ('Yorkshire Terrier-Rat Terrier Mix', 20.0, 105.18333329),
#  ('Lhasa Apso-Bichon Frise Mix', 20.0, 44781.266667),
#  ('Belgian Malinois-Chow Chow Mix', 20.0, 12890.4),
#  ('German Shepherd Dog-Pug Mix', 20.0, 50738.266667),
#  ('Pug-Pekingese Mix', 20.0, 22854.516667),
#  ('Australian Terrier-Lowchen Mix', 20.0, 2980.3999999),
#  ('Cairn Terrier-Pomeranian Mix', 20.0, 24061.05),
#  ('Australian Cattle Dog-Catahoula Leopard Dog Mix', 20.0, 96.083333362),
#  ('Belgian Malinois-German Shepherd Dog Mix', 20.0, 7122.1833333),
#  ('Affenpinscher-Brussels Griffon Mix', 20.0, 4435.8833333),
#  ('Australian Shepherd-Flat-Coated Retriever Mix', 20.0, 218872.71667),
#  ('Giant Schnauzer-American Eskimo Dog Mix', 20.0, 5864.8166666),
#  ('Akita-Labrador Retriever Mix', 20.0, 8020.6500001),
#  ('American Staffordshire Terrier-Dogo Argentino Mix', 20.0, 2870.3666668),
#  ('Cairn Terrier-Airedale Terrier Mix', 20.0, 40286.166667),
#  ('German Shepherd Dog-Keeshond Mix', 20.0, 3034.8416665835002),
#  ('Border Terrier-Cairn Terrier Mix', 20.0, 12591.716667),
#  ('Beagle-Shetland Sheepdog Mix', 20.0, 12980.95),
#  ('Whippet-Beagle Mix', 20.0, 2880.3333332),
#  ('Chinook-German Shepherd Dog Mix', 20.0, 6831.1166667),
#  ('Nova Scotia Duck Tolling Retriever-Chihuahua Mix', 20.0, 40470.966667),
#  ('Miniature Pinscher-Basenji Mix', 20.0, 10058.9),
#  ('Labrador Retriever-Bichon Frise Mix', 20.0, 9867.0833333),
#  ('Bullmastiff-Labrador Retriever Mix', 20.0, 79500.95),
#  ('Border Terrier-West Highland White Terrier Mix', 20.0, 8500.1833335),
#  ('Cavalier King Charles Spaniel-Pekingese Mix', 20.0, 9247.9666667),
#  ('Treeing Walker Coonhound-Parson Russell Terrier Mix', 20.0, 198885.93333),
#  ('Parson Russell Terrier-Maltese Mix', 20.0, 8761.2166667),
#  ('Welsh Terrier-Miniature Schnauzer Mix', 20.0, 1183.1833332),
#  ('Papillon-Chihuahua Mix', 20.0, 2141.9833333),
#  ('Papillon-German Spitz Mix', 20.0, 2608.95),
#  ('Miniature Schnauzer-Labrador Retriever Mix', 20.0, 46778.45),
#  ('Labrador Retriever-Belgian Malinois Mix', 20.0, 8722.2166668),
#  ('Doberman Pinscher-Dalmatian Mix', 20.0, 7399.0499999),
#  ('Poodle-Bernese Mountain Dog Mix', 20.0, 295520.51667),
#  ('German Shepherd Dog-Bloodhound Mix', 20.0, 10373.15),
#  ('Beagle-Chinese Shar-Pei Mix', 20.0, 45175.1),
#  ('Flat-Coated Retriever-Irish Water Spaniel Mix', 20.0, 21876.5),
#  ('Australian Cattle Dog-Bearded Collie Mix', 20.0, 2167.5833333),
#  ('Border Collie-Borzoi Mix', 20.0, 42249.783333),
#  ('Chihuahua-Boston Terrier Mix', 20.0, 30240.066667),
#  ('German Shorthaired Pointer-German Longhaired Pointer Mix', 20.0, 93665.35),
#  ('Miniature Schnauzer-Russell Terrier Mix', 20.0, 155674.43333),
#  ('American Staffordshire Terrier-Treeing Walker Coonhound Mix', 20.0, 4361.85),
#  ('Redbone Coonhound-Australian Shepherd Mix', 20.0, 6310.5833334),
#  ('American Pit Bull Terrier-Dogue de Bordeaux Mix', 20.0, 7455.6666666),
#  ('Pembroke Welsh Corgi-Border Collie Mix', 20.0, 40335.783333),
#  ('Brittany-Basset Hound Mix', 20.0, 129077.71667),
#  ('Border Collie-Bull Terrier Mix', 20.0, 263363.18333),
#  ('Siberian Husky-Mastiff Mix', 20.0, 7472.3833333),
#  ('Rottweiler-Greater Swiss Mountain Dog Mix', 20.0, 71818.55),
#  ('Pug-Poodle Mix', 20.0, 8926.5166668),
#  ('Havanese-Coton de Tulear Mix', 20.0, 70289.733333),
#  ('Whippet-Rhodesian Ridgeback Mix', 20.0, 7287.4333333),
#  ('Pomeranian-Boston Terrier Mix', 20.0, 14524.383333),
#  ('Pomeranian-Anatolian Shepherd Dog Mix', 20.0, 31810.716667),
#  ('Jack Russell Terrier-Labrador Retriever Mix', 20.0, 5771.15),
#  ('Australian Cattle Dog-Redbone Coonhound Mix', 20.0, 18663.233333),
#  ('Beagle-Greyhound Mix', 20.0, 245775.21667),
#  ('Basenji-English Springer Spaniel Mix', 20.0, 15932.833333),
#  ('American English Coonhound', 20.0, 21667.4),
#  ('Standard Poodle-Irish Setter Mix', 20.0, 4543.6833333),
#  ('American Hairless Terrier-Shetland Sheepdog Mix', 20.0, 40.783333236),
#  ('Beagle-Boston Terrier Mix', 20.0, 6969.6833333),
#  ('American Pit Bull Terrier-Border Collie Mix', 20.0, 8768.0999999),
#  ('Pug-Cocker Spaniel Mix', 20.0, 14520.383333),
#  ('Cardigan Welsh Corgi-Catahoula Leopard Dog Mix', 20.0, 2769.5833334),
#  ('Chinese Shar-Pei-Cocker Spaniel Mix', 20.0, 6700.1666666),
#  ('Jack Russell Terrier-Cavalier King Charles Spaniel Mix', 20.0, 18782.433333),
#  ('Wire Fox Terrier-Italian Greyhound Mix', 20.0, 18761.383333),
#  ('Border Collie-Great Pyrenees Mix', 20.0, 5630.0666667),
#  ('Rat Terrier-Yorkshire Terrier Mix', 20.0, 31384.183333),
#  ('Silky Terrier-Schipperke Mix', 20.0, 90.66666674),
#  ('Saluki-Greyhound Mix', 20.0, 17290.933333),
#  ('Keeshond-German Shepherd Dog Mix', 20.0, 2515.7),
#  ('Dachshund-Staffordshire Bull Terrier Mix', 20.0, 92.149999902),
#  ('Australian Cattle Dog-Treeing Walker Coonhound Mix', 20.0, 114.75000003),
#  ('Basset Hound-American Staffordshire Terrier Mix', 20.0, 198.66666667),
#  ('Siberian Husky-American English Coonhound Mix', 20.0, 4240.6833334),
#  ('American Staffordshire Terrier-Staffordshire Bull Terrier Mix', 20.0, 5775.5333332),
#  ('French Spaniel-German Shorthaired Pointer Mix', 20.0, 69655.566667),
#  ('Siberian Husky-Keeshond Mix', 20.0, 102.083333341),
#  ('Chihuahua-Miniature Australian Shepherd Mix', 20.0, 4355.55),
#  ('Shetland Sheepdog-Cairn Terrier Mix', 20.0, 1480.2833333),
#  ('Newfoundland-Poodle Mix', 20.0, 1363.9),
#  ('Vizsla-Dachshund Mix', 20.0, 18776.15),
#  ('Border Collie-Bernese Mountain Dog Mix', 20.0, 60664.766667),
#  ('Cocker Spaniel-Labrador Retriever Mix', 20.0, 147.63333337),
#  ('Pointer-Bracco Italiano Mix', 20.0, 808.25000011),
#  ('Chihuahua-Manchester Terrier Mix', 20.0, 23886.55),
#  ('American Pit Bull Terrier-Whippet Mix', 20.0, 4254.3166667),
#  ('Basset Hound-Pointer Mix', 20.0, 42021.183333),
#  ('Labrador Retriever-English Cocker Spaniel Mix', 20.0, 2908.5000002),
#  ('Bernese Mountain Dog-Standard Poodle Mix', 20.0, 1018.9),
#  ('Newfoundland-Standard Poodle Mix', 20.0, 73.96666663),
#  ('Border Terrier-Standard Schnauzer Mix', 20.0, 3870.8333333),
#  ('Jack Russell Terrier-Shih Tzu Mix', 20.0, 34737.383333),
#  ('Border Collie-Cavalier King Charles Spaniel Mix', 20.0, 15678.1),
#  ('Chow Chow-American Pit Bull Terrier Mix', 20.0, 801.25000002),
#  ('Miniature Australian Shepherd-Shetland Sheepdog Mix', 20.0, 4171.7833333),
#  ('Jack Russell Terrier-German Shepherd Dog Mix', 20.0, 7028.6833333),
#  ('Jack Russell Terrier-Whippet Mix', 20.0, 1131.25),
#  ('Poodle-German Wirehaired Pointer Mix', 20.0, 1491.6833333),
#  ('Entlebucher Mountain Dog', 19.5, 112759.712500775),
#  ('Australian Cattle Dog-Rottweiler Mix', 19.0, 166241.7999985),
#  ('Australian Shepherd-Pembroke Welsh Corgi Mix', 18.5, 401696.0916685),
#  ('-Labrador Retriever Mix', 18.5, 10661.86111104),
#  ('Rhodesian Ridgeback-Boxer Mix', 18.0, 169338.55833340003),
#  ('Chow Chow-Cocker Spaniel Mix', 18.0, 5941.8833333),
#  ('Siberian Husky-American Pit Bull Terrier Mix', 18.0, 20312.441667),
#  ('Brittany-Golden Retriever Mix', 18.0, 24700.083333),
#  ('Jack Russell Terrier-Manchester Terrier Mix', 18.0, 34416.8),
#  ('Border Terrier- Mix', 17.0, 1094780.3),
#  ('Border Collie-Staffordshire Bull Terrier Mix', 17.0, 208673.95833332298),
#  ('Beagle-Pekingese Mix', 17.0, 7281.7333332),
#  ('Dachshund-Golden Retriever Mix', 17.0, 25405.7),
#  ('Beagle-Treeing Walker Coonhound Mix', 17.0, 21033.216667),
#  ('Tibetan Terrier-Jack Russell Terrier Mix', 17.0, 88.583333305),
#  ('Shih Tzu-Bull Terrier Mix', 17.0, 111.03333341),
#  ('German Shepherd Dog-Treeing Walker Coonhound Mix', 17.0, 855.80000002),
#  ('Bearded Collie-Tibetan Terrier Mix', 16.0, 36135.4),
#  ('Pug-Chihuahua Mix', 16.0, 12658.0374999055),
#  ('American Pit Bull Terrier-Pointer Mix', 16.0, 56698.491666500006),
#  ('Puli', 16.0, 27327.090000019998),
#  ('Old English Sheepdog-Poodle Mix', 16.0, 18842.533333),
#  ('Bernese Mountain Dog-Poodle Mix', 16.0, 17155.5),
#  ('Parson Russell Terrier-Russell Terrier Mix', 16.0, 119592.58333),
#  ('Parson Russell Terrier-Poodle Mix', 16.0, 52384.36666665),
#  ('Cirneco dell"Etna', 16.0, 735816.46667),
#  ('Poodle-Border Collie Mix', 16.0, 37532.816667),
#  ('Italian Greyhound-Rat Terrier Mix', 16.0, 2777.5333334),
#  ('Brussels Griffon-Pug Mix', 16.0, 142455.75),
#  ('Yorkshire Terrier-Pomeranian Mix', 16.0, 13711.016666799998),
#  ('Rhodesian Ridgeback-Vizsla Mix', 16.0, 32109.083333),
#  ('Bulldog-Mastiff Mix', 16.0, 116433.41667),
#  ('Boxer-Poodle Mix', 16.0, 4264.0),
#  ('Miniature Schnauzer-West Highland White Terrier Mix', 16.0, 10043.683333),
#  ('Boston Terrier-Russell Terrier Mix', 16.0, 30466.383333),
#  ('Maltese-Havanese Mix', 16.0, 1588.7833333),
#  ('Great Pyrenees-Bernese Mountain Dog Mix', 16.0, 11584.183333),
#  ('Treeing Walker Coonhound-Pointer Mix', 16.0, 11941.45),
#  ('Wire Fox Terrier-Dachshund Mix', 16.0, 4347.6833334),
#  ('Border Collie-German Shorthaired Pointer Mix', 16.0, 5738.5833333),
#  ('Toy Fox Terrier-Australian Shepherd Mix', 16.0, 11228.016667),
#  ('Wire Fox Terrier-Bulldog Mix', 16.0, 93074.833333),
#  ('Belgian Sheepdog-Chow Chow Mix', 16.0, 86.833333244),
#  ('Whippet-Rat Terrier Mix', 16.0, 12800.016667),
#  ('Hovawart-German Shepherd Dog Mix', 16.0, 5791.75),
#  ('Labrador Retriever-Airedale Terrier Mix', 16.0, 260.69999998),
#  ('Airedale Terrier-Catahoula Leopard Dog Mix', 16.0, 1416.75),
#  ('American Eskimo Dog-Pomeranian Mix', 15.75, 41721.5750000475),
#  ('Pug-Beagle Mix', 15.666666666666666, 36623.60555546667),
#  ('Chesapeake Bay Retriever-Labrador Retriever Mix', 15.666666666666666, 6173.194444468667),
#  ('Pug-Miniature Pinscher Mix', 15.5, 20144.09166685),
#  ('St. Bernard-Labrador Retriever Mix', 15.5, 305388.0500015),
#  ('Norwegian Buhund', 15.5, 13723.8874999347),
#  ('American Staffordshire Terrier-Bullmastiff Mix', 15.5, 69471.091667),
#  ('German Shepherd Dog-Australian Cattle Dog Mix', 15.5, 19428.474999899998),
#  ('Cavalier King Charles Spaniel-Cocker Spaniel Mix', 15.5, 9361.96666665),
#  ('German Shepherd Dog-American Staffordshire Terrier Mix', 15.5, 23957.70000005),
#  ('Standard Schnauzer-Poodle Mix', 15.5, 28172.5),
#  ('Beagle-Poodle Mix', 15.5, 4405.724999955),
#  ('Black and Tan Coonhound-Labrador Retriever Mix', 15.5, 106562.35833169309),
#  ('Australian Cattle Dog-Border Collie Mix', 15.285714285714286, 98579.44285735728),
#  ('Labrador Retriever-Golden Retriever Mix', 15.098445595854923, 39364.16260790755),
#  ('Golden Retriever-Collie Mix', 15.0, 108356.21666679134),
#  ('Cardigan Welsh Corgi-German Shepherd Dog Mix', 15.0, 287421.100000004),
#  ('Cocker Spaniel-Bichon Frise Mix', 15.0, 27437.133333),
#  ('Chihuahua-Poodle Mix', 15.0, 27476.1),
#  ('Border Collie-American Foxhound Mix', 15.0, 8630.7166666),
#  ('Australian Shepherd-Cocker Spaniel Mix', 15.0, 221741.7083333),
#  ('Keeshond-American Eskimo Dog Mix', 15.0, 11347.15),
#  ('Pomeranian-Toy Fox Terrier Mix', 15.0, 9104.8833332),
#  ('Rottweiler-Australian Cattle Dog Mix', 15.0, 63.766666634),
#  ('German Shepherd Dog-Basset Hound Mix', 15.0, 1558.7333334),
#  ('Australian Kelpie-Border Collie Mix', 15.0, 24612.483333),
#  ('American Staffordshire Terrier-Lancashire Heeler Mix', 15.0, 3013.4666666),
#  ('St. Bernard-Standard Poodle Mix', 15.0, 9827.7499999),
#  ('Siberian Husky-Australian Shepherd Mix', 14.666666666666666, 12850.549999993333),
#  ('Border Collie-Australian Cattle Dog Mix', 14.666666666666666, 78451.43240759514),
#  ('Beauceron', 14.666666666666666, 20143.524074041557),
#  ('Vizsla- Mix', 14.5, 99361.225),
#  ('Tibetan Spaniel', 14.5, 867.4208333557501),
#  ('Akita-Siberian Husky Mix', 14.5, 25574.2833331645),
#  ('Pointer-Labrador Retriever Mix', 14.333333333333334, 73835.20555563267),
#  ('Shetland Sheepdog-Border Collie Mix', 14.333333333333334, 20911.99999981),
#  ('Smooth Fox Terrier', 14.333333333333334, 71857.85555552832),
#  ('Labrador Retriever-Great Dane Mix', 14.333333333333334, 14602.427777782),
#  ('Bouvier des Flandres', 14.304347826086957, 92807.46304318635),
#  ('German Shepherd Dog-Pembroke Welsh Corgi Mix', 14.0, 481032.75),
#  ('Beagle-Schipperke Mix', 14.0, 27339.1),
#  ('German Shepherd Dog-Belgian Tervuren Mix', 14.0, 75157.483333),
#  ('Affenpinscher', 14.0, 47075.373809546996),
#  ('Yorkshire Terrier- Mix', 14.0, 41802.399999825),
#  ('American Water Spaniel', 14.0, 58889.4791667455),
#  ('Poodle-Lhasa Apso Mix', 14.0, 3950.561111129666),
#  ('Miniature Pinscher-Chihuahua Mix', 14.0, 81.01666661),
#  ('Collie-German Shepherd Dog Mix', 14.0, 106303.57916664725),
#  ('German Shepherd Dog-Central Asian Shepherd Dog Mix', 14.0, 152634.5),
#  ('Australian Cattle Dog-Beagle Mix', 14.0, 19660.208333345),
#  ('German Shepherd Dog-Rhodesian Ridgeback Mix', 14.0, 8986.499999961501),
#  ('American Staffordshire Terrier-Rhodesian Ridgeback Mix', 14.0, 9238.8166667),
#  ('Samoyed-Shetland Sheepdog Mix', 14.0, 91.616666614),
#  ('Basset Hound-Australian Shepherd Mix', 14.0, 17349.8),
#  ('Australian Shepherd-Bearded Collie Mix', 14.0, 361973.31667),
#  ('Pomeranian-American Eskimo Dog Mix', 14.0, 79192.05),
#  ('Golden Retriever-Bullmastiff Mix', 14.0, 32987.116667),
#  ('American Pit Bull Terrier-Staffordshire Bull Terrier Mix', 14.0, 4793.2166666),
#  ('Miniature Schnauzer-Miniature Australian Shepherd Mix', 14.0, 112555.3),
#  ('Golden Retriever-Plott Mix', 14.0, 120402.33333),
#  ('Beagle-Miniature Schnauzer Mix', 14.0, 66073.0),
#  ('Boston Terrier-American Staffordshire Terrier Mix', 14.0, 10145.25),
#  ('Toy Fox Terrier-Shih Tzu Mix', 14.0, 74.233333358),
#  ('German Shorthaired Pointer-Rottweiler Mix', 14.0, 10127.6),
#  ('Mastiff-Flat-Coated Retriever Mix', 14.0, 19052.683333),
#  ('Giant Schnauzer', 13.875, 61947.62708379325),
#  ('Golden Retriever-Labrador Retriever Mix', 13.79245283018868, 32732.841823929568),
#  ('Labrador Retriever-Collie Mix', 13.75, 36456.90833252984),
#  ('Poodle-Old English Sheepdog Mix', 13.5, 25291.2500000385),
#  ('Pug-Wire Fox Terrier Mix', 13.5, 409272.0083335),
#  ('Chinese Crested-Poodle Mix', 13.5, 30970.05000015),
#  ('Field Spaniel', 13.5, 46619.419444374675),
#  ('Russell Terrier-Beagle Mix', 13.5, 36845.38333335),
#  ('Flat-Coated Retriever- Mix', 13.5, 110125.0333350405),
#  ('Rat Terrier-Chihuahua Mix', 13.5, 52542.704166604),
#  ('Rat Terrier-Russell Terrier Mix', 13.5, 1850.3583332885),
#  ('Golden Retriever-Chow Chow Mix', 13.5, 5997.32499995),
#  ('Yorkshire Terrier-Silky Terrier Mix', 13.5, 6552.4583333),
#  ('Belgian Malinois-Siberian Husky Mix', 13.5, 21740.3833332),
#  ('Bichon Frise-Cocker Spaniel Mix', 13.5, 2178.841666755),
#  ('Pomeranian-Rat Terrier Mix', 13.5, 1152.708333226),
#  ('Poodle-Havanese Mix', 13.5, 1505.075000085),
#  ('Kooikerhondje', 13.4, 13616.659999995998),
#  ('German Shorthaired Pointer-Labrador Retriever Mix', 13.4, 143598.2599986413),
#  ('Icelandic Sheepdog', 13.375, 48599.760416323414),
#  ('Chihuahua-Italian Greyhound Mix', 13.333333333333334, 3911.472222343333),
#  ('Komondor', 13.333333333333334, 4593.611110977767),
#  ('Australian Terrier', 13.23076923076923, 66054.99871766107),
#  ('Chihuahua-Russell Terrier Mix', 13.2, 34307.4166672808),
#  ('Pyrenean Shepherd', 13.142857142857142, 30023.204762466285),
#  ('Norwegian Elkhound', 13.0, 19257.535714300004),
#  ('Afghan Hound', 13.0, 1472.7366666566),
#  ('Cocker Spaniel-Cavalier King Charles Spaniel Mix', 13.0, 36739.041667),
#  ('German Longhaired Pointer', 13.0, 79.833333325),
#  ('Golden Retriever-Basset Hound Mix', 13.0, 168348.26667),
#  ('Shih Tzu-Dachshund Mix', 13.0, 1548.2),
#  ('Border Collie-Brittany Mix', 13.0, 14497.5333335),
#  ('Golden Retriever-Pembroke Welsh Corgi Mix', 13.0, 7228.8499999),
#  ('American Pit Bull Terrier-Bullmastiff Mix', 13.0, 2357.3277777666667),
#  ('Staffordshire Bull Terrier-Australian Cattle Dog Mix', 13.0, 6703.900000196233),
#  ('Shetland Sheepdog-Collie Mix', 13.0, 60740.1),
#  ('Cocker Spaniel-Miniature Pinscher Mix', 13.0, 27205.35),
#  ('Dogo Argentino-American Pit Bull Terrier Mix', 13.0, 17497.9),
#  ('Ibizan Hound-Greyhound Mix', 13.0, 18727.383333),
#  ('Scottish Terrier', 12.894736842105264, 111989.47631562942),
#  ('German Shepherd Dog-Rottweiler Mix', 12.857142857142858, 8459.590476186428),
#  ('Labrador Retriever-Australian Cattle Dog Mix', 12.833333333333334, 2091.4444444233336),
#  ('Chow Chow-Labrador Retriever Mix', 12.75, 42382.60000010001),
#  ('Border Collie-Shetland Sheepdog Mix', 12.75, 15525.616666725002),
#  ('Karelian Bear Dog', 12.666666666666666, 328089.127779),
#  ('Pekingese-Poodle Mix', 12.5, 165657.5250009775),
#  ('Bernese Mountain Dog-Great Pyrenees Mix', 12.5, 69828.1916665),
#  ('Pug-Boston Terrier Mix', 12.5, 17351.183333433),
#  ('Labrador Retriever-Rhodesian Ridgeback Mix', 12.5, 63487.82500000405),
#  ('Miniature Schnauzer-Poodle Mix', 12.4375, 39991.654166784116),
#  ('Australian Kelpie', 12.428571428571429, 39054.41428618937),
#  ('Labrador Retriever- Mix', 12.25, 8445.63749994285),
#  ('Wirehaired Pointing Griffon', 12.25, 145160.60208339168),
#  ('Labrador Retriever-Weimaraner Mix', 12.2, 77688.94888890251),
#  ('Bichon Frise-Shih Tzu Mix', 12.1875, 77564.35000042114),
#  ('Samoyed', 12.185185185185185, 74047.32469145443),
#  ('Australian Shepherd-Australian Cattle Dog Mix', 12.125, 22345.39791709375),
#  ('Pembroke Welsh Corgi', 12.012195121951219, 38173.40203249333),
#  ('German Shepherd Dog-Border Collie Mix', 12.0, 21105.506666561974),
#  ('Great Dane-Labrador Retriever Mix', 12.0, 12953.583333193),
#  ('Danish-Swedish Farmdog', 12.0, 44535.216667511),
#  ('Pekingese-Dachshund Mix', 12.0, 60583.816667),
#  ('American Pit Bull Terrier-Australian Cattle Dog Mix', 12.0, 130.6416667545),
#  ('Dachshund-Yorkshire Terrier Mix', 12.0, 149968.25000164247),
#  ('Spanish Water Dog', 12.0, 33186.83333260963),
#  ('Shih Tzu-Pomeranian Mix', 12.0, 2890.774999955),
#  ('Beagle-Dachshund Mix', 12.0, 7257.2944444253335),
#  ('Siberian Husky-Rottweiler Mix', 12.0, 46823.25000013615),
#  ('Australian Cattle Dog-Siberian Husky Mix', 12.0, 205.224999884),
#  ('Border Collie-American Pit Bull Terrier Mix', 12.0, 5689.816666451001),
#  ('Beagle-Chihuahua Mix', 12.0, 8706.7583335),
#  ('Catahoula Leopard Dog-Boxer Mix', 12.0, 1462.0499999),
#  ('Poodle-American Pit Bull Terrier Mix', 12.0, 57909.4),
#  ('Miniature Schnauzer-Wire Fox Terrier Mix', 12.0, 7235.9499998925),
#  ('Whippet-Greyhound Mix', 12.0, 9268.8249998598),
#  ('Tibetan Spaniel-Papillon Mix', 12.0, 17693.75),
#  ('Bichon Frise-Cavalier King Charles Spaniel Mix', 11.88888888888889, 9190.607407350333),
#  ('Poodle-Cavalier King Charles Spaniel Mix', 11.875, 105753.57708418401),
#  ('Siberian Husky-German Shepherd Dog Mix', 11.823529411764707, 47914.24215688663),
#  ('Cockapoo', 11.808080808080808, 60199.95151533151),
#  ('Shetland Sheepdog', 11.757352941176471, 29726.710661823454),
#  ('Beagle-Bluetick Coonhound Mix', 11.75, 8299.933333314999),
#  ('English Cocker Spaniel', 11.735294117647058, 51494.081372336055),
#  ('Australian Cattle Dog- Mix', 11.666666666666666, 24668.633333447),
#  ('Labrador Retriever-Rottweiler Mix', 11.666666666666666, 37136.716666448316),
#  ('Russell Terrier-Shih Tzu Mix', 11.666666666666666, 7090.966666734334),
#  ('Dachshund-Poodle Mix', 11.666666666666666, 74713.749998912),
#  ('Lowchen', 11.666666666666666, 85736.905554313),
#  ('Labrador Retriever-Pointer Mix', 11.666666666666666, 41519.686110540664),
#  ('Labrador Retriever-Mastiff Mix', 11.666666666666666, 55687.59444333467),
#  ('Beagle-Parson Russell Terrier Mix', 11.666666666666666, 117686.70000097832),
#  ('Australian Cattle Dog-German Shepherd Dog Mix', 11.636363636363637, 13701.7545454906),
#  ('Belgian Malinois', 11.625, 49736.51909702227),
#  ('Norfolk Terrier', 11.625, 17067.479166693975),
#  ('Collie-Shetland Sheepdog Mix', 11.5, 5414.816666807),
#  ('Poodle-Maltese Mix', 11.5, 72646.07738051182),
#  ('Boxer-Vizsla Mix', 11.5, 524.2916667100001),
#  ('German Shepherd Dog-Doberman Pinscher Mix', 11.5, 34477.30000006833),
#  ('Smooth Fox Terrier-Whippet Mix', 11.5, 602.7916666646499),
#  ('Shorkie', 11.4, 47790.61222200822),
#  ('Portuguese Water Dog', 11.383561643835616, 77665.67260261142),
#  ('Miniature American Shepherd', 11.37037037037037, 33564.70370390127),
#  ('Australian Labradoodle', 11.342105263157896, 38443.21403545679),
#  ('Australian Shepherd', 11.3342939481268, 46627.8174351879),
#  ('French Spaniel', 11.333333333333334, 2783.1777777496663),
#  ('German Shepherd Dog-Boxer Mix', 11.333333333333334, 60962.23888778967),
#  ('Siberian Husky-American Staffordshire Terrier Mix', 11.333333333333334, 12530.749999987798),
#  ('Border Collie-Greyhound Mix', 11.25, 5811.074999883074),
#  ('Australian Shepherd-Poodle Mix', 11.23076923076923, 123817.0833359444),
#  ('American Eskimo Dog', 11.083333333333334, 31778.320833311318),
#  ('Soft Coated Wheaten Terrier', 11.08, 52906.649555421805),
#  ('Doberman Pinscher', 11.074766355140186, 41020.36230524853),
#  ('Golden Retriever-Poodle Mix', 11.03125, 28757.90156248263),
#  ('Maltese-Yorkshire Terrier Mix', 11.030303030303031, 25887.905555658897),
#  ('Coton de Tulear', 11.026315789473685, 33411.147807085166),
#  ('German Shepherd Dog-Nova Scotia Duck Tolling Retriever Mix', 11.0, 40677.116667),
#  ('Finnish Spitz', 11.0, 54194.71666659545),
#  ('Russell Terrier-Miniature Pinscher Mix', 11.0, 69336.8),
#  ('Pug-Smooth Fox Terrier Mix', 11.0, 40430.966667),
#  ('Poodle-Dachshund Mix', 11.0, 27.233333309),
#  ('Border Collie-Pembroke Welsh Corgi Mix', 11.0, 7157.6999999),
#  ('Kerry Blue Terrier', 11.0, 81987.450000126),
#  ('Briard', 11.0, 29591.827777320388),
#  ('German Shepherd Dog-Poodle Mix', 11.0, 6301.9958334375),
#  ('Border Collie-Saluki Mix', 11.0, 151294.4),
#  ('Whippet-German Shepherd Dog Mix', 11.0, 161032.98333),
#  ('Dachshund-Doberman Pinscher Mix', 11.0, 14504.666667),
#  ('American Pit Bull Terrier-Mastiff Mix', 11.0, 23051.716667),
#  ('Pumi', 11.0, 3252.85),
#  ('Labrador Retriever-Boxer Mix', 11.0, 4471.429166593274),
#  ('Poodle-Chihuahua Mix', 11.0, 87.933333313),
#  ('Australian Cattle Dog-Anatolian Shepherd Dog Mix', 11.0, 81.999999972),
#  ('Border Collie-Collie Mix', 11.0, 15358.166667),
#  ('Chinese Shar-Pei-Boerboel Mix', 11.0, 142477.63333),
#  ('Border Collie-Flat-Coated Retriever Mix', 11.0, 2945.4),
#  ('Boxer-Golden Retriever Mix', 11.0, 85.283333435),
#  ('Miniature Schnauzer-Cairn Terrier Mix', 11.0, 26.908333311),
#  ('Bernese Mountain Dog-Rottweiler Mix', 11.0, 37851.616667),
#  ('Airedale Terrier-German Shepherd Dog Mix', 11.0, 27101.016667),
#  ('Beagle-Golden Retriever Mix', 11.0, 1294.15),
#  ('Silky Terrier-Lhasa Apso Mix', 11.0, 2448.9833333),
#  ('Cavalier King Charles Spaniel-Australian Shepherd Mix', 11.0, 4119.7833334),
#  ('Labrador Retriever-Catahoula Leopard Dog Mix', 11.0, 143.30000007),
#  ('Basset Hound-Australian Cattle Dog Mix', 11.0, 7411.9999999),
#  ('Cocker Spaniel-Pug Mix', 11.0, 5741.7499999),
#  ('German Shepherd Dog-Shetland Sheepdog Mix', 11.0, 50524.883333),
#  ('American Pit Bull Terrier-Cane Corso Mix', 11.0, 1398.9833332),
#  ('American Pit Bull Terrier-Treeing Tennessee Brindle Mix', 11.0, 15864.266667),
#  ('Rottweiler-Komondor Mix', 11.0, 2989.3666666),
#  ('Miniature Australian Shepherd', 11.0, 8801.727450944776),
#  ('German Shepherd Dog-Black and Tan Coonhound Mix', 11.0, 20221.716667),
#  ('Papillon-English Springer Spaniel Mix', 11.0, 9583.6500001),
#  ('Mastiff-Great Pyrenees Mix', 11.0, 41875.95),
#  ('Bichon Frise-Miniature Schnauzer Mix', 11.0, 10231.233333),
#  ('Australian Cattle Dog-Bull Terrier Mix', 11.0, 51014.675000015006),
#  ('Siberian Husky-Greyhound Mix', 11.0, 20036.583333),
#  ('Border Collie-Rhodesian Ridgeback Mix', 11.0, 25961.283333),
#  ('Yorkshire Terrier-Havanese Mix', 11.0, 5744.4166667),
#  ('Border Collie-Pointer Mix', 11.0, 134876.61667),
#  ('Bloodhound-Bull Terrier Mix', 11.0, 44.266666618),
#  ('Yorkshire Terrier-Belgian Malinois Mix', 11.0, 54.183333313),
#  ('Dalmatian-Australian Shepherd Mix', 11.0, 45.266666732),
#  ('Boxer-Australian Shepherd Mix', 11.0, 94.283333403),
#  ('Border Collie-Standard Poodle Mix', 11.0, 10631.716667),
#  ('Treeing Walker Coonhound-Great Dane Mix', 11.0, 8592.5666666),
#  ('Brittany', 10.944444444444445, 59352.679012165085),
#  ('Collie', 10.944444444444445, 79676.73456796401),
#  ('English Setter', 10.875, 48869.498957889984),
#  ('Irish Terrier', 10.857142857142858, 14468.07500002358),
#  ('Gordon Setter', 10.833333333333334, 68230.79722271816),
#  ('Boykin Spaniel', 10.8, 132595.31333337273),
#  ('American Pit Bull Terrier-Boxer Mix', 10.8, 44064.237777558345),
#  ('Irish Water Spaniel', 10.8, 4241.5633333208),
#  ('American Staffordshire Terrier-Bulldog Mix', 10.8, 187572.08666661725),
#  ('Nova Scotia Duck Tolling Retriever', 10.758620689655173, 33259.44425244803),
#  ('Doberman Pinscher-German Shepherd Dog Mix', 10.75, 13429.37500001825),
#  ('Poodle', 10.732782369146005, 46892.78034901184),
#  ('Irish Red and White Setter', 10.666666666666666, 31481.316666933333),
#  ('Swedish Vallhund', 10.666666666666666, 45647.561112128664),
#  ('Black and Tan Coonhound', 10.666666666666666, 45238.99999986667),
#  ('Yorkshire Terrier-Shih Tzu Mix', 10.666666666666666, 69233.4861116415),
#  ('Australian Shepherd-German Shepherd Dog Mix', 10.6, 94088.97666656993),
#  ('Border Collie-German Shepherd Dog Mix', 10.583333333333334, 10170.968055549834),
#  ('Labrador Retriever', 10.57179054054054, 38349.53985079198),
#  ('Weimaraner', 10.5625, 65685.85937510818),
#  ('Chinook', 10.5, 12868.424999825),
#  ('Australian Shepherd- Mix', 10.5, 186614.083333254),
#  ('Glen of Imaal Terrier', 10.5, 83983.6125000025),
#  ('Rhodesian Ridgeback-Labrador Retriever Mix', 10.5, 176480.41666664026),
#  ('Poodle-Rat Terrier Mix', 10.5, 11259.0083335),
#  ('Alaskan Malamute-Siberian Husky Mix', 10.5, 12058.879166556751),
#  ('Belgian Malinois-Labrador Retriever Mix', 10.5, 13852.783333229501),
#  ('Jack Russell Terrier-Welsh Terrier Mix', 10.5, 1365.43333325),
#  ('Greyhound-Border Collie Mix', 10.5, 3627.475),
#  ('Finnish Lapphund', 10.428571428571429, 192674.4904761527),
#  ('Yorkshire Terrier-Maltese Mix', 10.421052631578947, 18010.272806830075),
#  ('Border Collie-Australian Shepherd Mix', 10.4, 18027.21166678406),
#  ('Keeshond', 10.4, 59139.97555576634),
#  ('German Shorthaired Pointer', 10.372549019607844, 29480.364052284855),
#  ('Border Terrier', 10.368421052631579, 62634.06578910663),
#  ('American Pit Bull Terrier-Rhodesian Ridgeback Mix', 10.333333333333334, 1957.7888889020003),
#  ('Rhodesian Ridgeback', 10.303030303030303, 43097.925000012634),
#  ('Pointer', 10.285714285714286, 32359.94999960499),
#  ('Standard Schnauzer', 10.25925925925926, 43753.33024664907),
#  ('Australian Shepherd-Great Pyrenees Mix', 10.25, 5463.175000019501),
#  ('Golden Retriever', 10.227848101265822, 39960.15815747411),
#  ('Flat-Coated Retriever', 10.209302325581396, 13495.229457339894),
#  ('Irish Setter', 10.1875, 10775.403125045668),
#  ('Vizsla', 10.180555555555555, 38921.20393516499),
#  ('Labradoodle', 10.17910447761194, 37650.494776065636),
#  ('Shih Tzu', 10.173913043478262, 57839.08528994619),
#  ('Labrador Retriever-Border Collie Mix', 10.172413793103448, 44517.614368082024),
#  ('Border Collie', 10.172131147540984, 45154.1688524252),
#  ('Redbone Coonhound', 10.166666666666666, 13050.350000006001),
#  ('West Highland White Terrier', 10.121621621621621, 10734.312612580956),
#  ('Welsh Springer Spaniel', 10.083333333333334, 19384.531944378086),
#  ('Beagle', 10.076923076923077, 27441.49568765019),
#  ('Puggle', 10.069767441860465, 15236.120542662384),
#  ('German Shepherd Dog', 10.06338028169014, 35893.686267602825),
#  ('Golden Doodle', 10.043010752688172, 33968.831421707335),
#  ('American Staffordshire Terrier-Labrador Retriever Mix', 10.0, 77212.25000002135),
#  ('German Shepherd Dog-Golden Retriever Mix', 10.0, 115249.50000027582),
#  ('Border Collie-Golden Retriever Mix', 10.0, 44834.83333299179),
#  ('Doberman Pinscher-Black and Tan Coonhound Mix', 10.0, 21575.433333),
#  ('Manchester Terrier', 10.0, 15644.78333337008),
#  ('Chihuahua-Pembroke Welsh Corgi Mix', 10.0, 2764.6666666972),
#  ('Pomeranian-Papillon Mix', 10.0, 117509.90555555),
#  ('Bull Terrier-American Foxhound Mix', 10.0, 30165.433333),
#  ('Siberian Husky-Alaskan Malamute Mix', 10.0, 80.500000065),
#  ('Standard Poodle-Chinese Shar-Pei Mix', 10.0, 165912.0),
#  ('Lancashire Heeler-Australian Cattle Dog Mix', 10.0, 174325.4),
#  ('Brittany-Pointer Mix', 10.0, 1599.6166668),
#  ('Siberian Husky-Boxer Mix', 10.0, 68.43333329800001),
#  ('Beagle-Jack Russell Terrier Mix', 10.0, 43226.533333),
#  ('Poodle-Australian Cattle Dog Mix', 10.0, 10125.3833332805),
#  ('Standard Poodle-Standard Schnauzer Mix', 10.0, 18686.733333),
#  ('Miniature Schnauzer', 9.969325153374234, 32992.51697340597),
#  ('Cocker Spaniel', 9.96808510638298, 37183.599822734504),
#  ('St. Bernard', 9.909090909090908, 52897.13409073958),
#  ('Australian Cattle Dog', 9.905882352941177, 43294.12588240404),
#  ('Shiba Inu', 9.88888888888889, 54213.8962969836),
#  ('Border Collie-Labrador Retriever Mix', 9.852941176470589, 45768.968627694645),
#  ('Belgian Tervuren', 9.833333333333334, 45778.74722206801),
#  ('Dutch Shepherd', 9.833333333333334, 60460.043055525544),
#  ('Cairn Terrier', 9.825, 24578.268750051757),
#  ('Bedlington Terrier', 9.8, 14439.21666667806),
#  ('German Shepherd Dog-Alaskan Malamute Mix', 9.8, 44354.67000064),
#  ('German Shepherd Dog-American Pit Bull Terrier Mix', 9.8, 22676.576666665842),
#  ('Poodle-Soft Coated Wheaten Terrier Mix', 9.8, 6632.8133333986),
#  ('Poodle-Miniature Schnauzer Mix', 9.73913043478261, 27760.081159482634),
#  ('Pug', 9.700934579439252, 26976.240965632504),
#  ('Norwich Terrier', 9.7, 54025.1716666288),
#  ('Australian Cattle Dog-Labrador Retriever Mix', 9.7, 34946.349999654034),
#  ('Mixed', 9.688152098307443, 36869.09039339122),
#  ('Chihuahua-Beagle Mix', 9.666666666666666, 5556.611111066667),
#  ('Papillon', 9.634615384615385, 35011.47083329997),
#  ('Cocker Spaniel-Poodle Mix', 9.620689655172415, 13848.37988508455),
#  ('Rat Terrier', 9.615384615384615, 47362.30448723533),
#  ('Whippet', 9.612903225806452, 47338.25698904572),
#  ('Silky Terrier', 9.6, 132562.26500330042),
#  ('German Shepherd Dog-Belgian Malinois Mix', 9.6, 4364.88333332914),
#  ('Lhasa Apso-Poodle Mix', 9.571428571428571, 108299.81666618814),
#  ('Siberian Husky', 9.548387096774194, 37793.268817134274),
#  ('Akita', 9.541666666666666, 55802.714583385394),
#  ('Cavalier King Charles Spaniel-Poodle Mix', 9.526315789473685, 21150.927192850282),
#  ('Rottweiler', 9.525641025641026, 18845.844444401115),
#  ('Mudi', 9.5, 9322.320833322274),
#  ('Alaskan Malamute', 9.5, 49533.098610969755),
#  ('Belgian Sheepdog', 9.5, 2435.5777778237502),
#  ('Beagle-American Eskimo Dog Mix', 9.5, 1590.5000001055),
#  ('German Pinscher', 9.5, 21119.7958333175),
#  ('Labrador Retriever-Doberman Pinscher Mix', 9.5, 19250.7083335),
#  ('Collie-Golden Retriever Mix', 9.5, 1490.9249999639999),
#  ('Alaskan Malamute-German Shepherd Dog Mix', 9.5, 1129.2166666824999),
#  ('Chihuahua-Yorkshire Terrier Mix', 9.454545454545455, 14567.737878819818),
#  ('Catahoula Leopard Dog', 9.444444444444445, 17750.54629612399),
#  ('Cardigan Welsh Corgi', 9.428571428571429, 4842.023809492605),
#  ('Greyhound', 9.425925925925926, 49269.83086425738),
#  ('Wire Fox Terrier', 9.416666666666666, 61331.62638942319),
#  ('Bernese Mountain Dog', 9.404255319148936, 51811.63156052799),
#  ('German Shepherd Dog-Siberian Husky Mix', 9.35, 28535.79666664985),
#  ('English Springer Spaniel', 9.339285714285714, 29945.186458153534),
#  ('German Shepherd Dog-Beagle Mix', 9.333333333333334, 204568.56666663665),
#  ('American Staffordshire Terrier-Border Collie Mix', 9.333333333333334, 66916.55000118566),
#  ('Pug-Shih Tzu Mix', 9.333333333333334, 12946.316666835335),
#  ('Boxer', 9.329842931937172, 40058.70898777516),
#  ('Cavalier King Charles Spaniel-Bichon Frise Mix', 9.272727272727273, 28722.307576048494),
#  ('Labrador Retriever-German Shepherd Dog Mix', 9.25, 16965.660714586724),
#  ('Mastiff', 9.238095238095237, 6161.822222196795),
#  ('Boxer-American Staffordshire Terrier Mix', 9.2, 15758.373333321),
#  ('Chinese Shar-Pei', 9.2, 36500.411666622225),
#  ('Greyhound-Labrador Retriever Mix', 9.2, 8396.09999998698),
#  ('Siberian Husky-Labrador Retriever Mix', 9.2, 4550.2900000566),
#  ('Dalmatian', 9.1875, 62847.13333341621),
#  ('American Staffordshire Terrier', 9.175438596491228, 26110.894444388436),
#  ('Pomapoo', 9.166666666666666, 21695.091666668643),
#  ('Newfoundland', 9.151515151515152, 28719.99545473895),
#  ('Old English Sheepdog', 9.125, 95206.77604188475),
#  ('Australian Cattle Dog-Australian Shepherd Mix', 9.125, 8521.670833330712),
#  ('Bichon Frise', 9.05, 17890.957291708906),
#  ('French Bulldog', 9.0, 54843.31969705949),
#  ('Shih Tzu-Maltese Mix', 9.0, 18023.29374998274),
#  ('Irish Wolfhound', 9.0, 124580.25333403998),
#  ('Treeing Walker Coonhound', 9.0, 41364.10952360524),
#  ('Spinone Italiano', 9.0, 47685.31111056667),
#  ('Labrador Retriever-American Pit Bull Terrier Mix', 9.0, 19296.09545437159),
#  ('Borzoi', 9.0, 58.783333341),
#  ('Basset Hound-German Shepherd Dog Mix', 9.0, 43206.4666664654),
#  ('Boxer- Mix', 9.0, 10632.64166680485),
#  ('Keeshond-Chow Chow Mix', 9.0, 60305.1083335),
#  ('-Boxer Mix', 9.0, 28161.616666864),
#  ('Chihuahua-Cardigan Welsh Corgi Mix', 9.0, 33171.4749999654),
#  ('Siberian Husky-Border Collie Mix', 9.0, 21099.411111115198),
#  ('Havanese-Shih Tzu Mix', 9.0, 522768.21667),
#  ('Bulldog-Bullmastiff Mix', 9.0, 55884.183333),
#  ('Plott', 9.0, 7282.488888813033),
#  ('Soft Coated Wheaten Terrier-Poodle Mix', 9.0, 1793.4833333),
#  ('American Eskimo Dog-Shiba Inu Mix', 9.0, 10231.233333),
#  ('Greyhound-Irish Wolfhound Mix', 9.0, 41860.316667),
#  ('Italian Greyhound-Miniature Pinscher Mix', 9.0, 11728.975000049999),
#  ('Chesapeake Bay Retriever-Siberian Husky Mix', 9.0, 473.4499999582),
#  ('Australian Terrier-Parson Russell Terrier Mix', 9.0, 180185.78333),
#  ('Boston Terrier-Pomeranian Mix', 9.0, 11044.6750001),
#  ('American Staffordshire Terrier-Dogue de Bordeaux Mix', 9.0, 11760.8333335),
#  ('Catahoula Leopard Dog-Bluetick Coonhound Mix', 9.0, 237.3916665925),
#  ('Plott-Labrador Retriever Mix', 9.0, 10120.366667),
#  ('Dutch Shepherd-Labrador Retriever Mix', 9.0, 67481.983333),
#  ('Maltese-Shih Tzu Mix', 8.923076923076923, 10530.149999993579),
#  ('Welsh Terrier', 8.916666666666666, 22335.354166653942),
#  ('Lagotto Romagnolo', 8.88888888888889, 35109.08333298776),
#  ('Labrador Retriever-Beagle Mix', 8.875, 14054.252083387373),
#  ('Other', 8.82258064516129, 21726.979905921668),
#  ('Bull Terrier', 8.8, 17993.128333371722),
#  ('Labrador Retriever-Siberian Husky Mix', 8.8, 24257.6133326424),
#  ('Labrador Retriever-Dachshund Mix', 8.75, 3426.9583332957004),
#  ('Petit Basset Griffon Vendeen', 8.75, 2552.0166667652497),
#  ('Mastiff-Labrador Retriever Mix', 8.75, 16898.370833493),
#  ('Havanese-Poodle Mix', 8.714285714285714, 32486.052381488968),
#  ('Neapolitan Mastiff', 8.666666666666666, 11586.327777911998),
#  ('Poodle-Golden Retriever Mix', 8.666666666666666, 5893.4277778135),
#  ('American Pit Bull Terrier', 8.654929577464788, 32408.94624426836),
#  ('German Wirehaired Pointer', 8.642857142857142, 5865.673809573321),
#  ('Chihuahua-Pug Mix', 8.625, 56452.76875045406),
#  ('Lhasa Apso', 8.6, 32805.65555554841),
#  ('Poodle-Labrador Retriever Mix', 8.6, 1783.0599999799997),
#  ('Labrador Retriever-German Shorthaired Pointer Mix', 8.571428571428571, 1227.935714242143),
#  ('Chihuahua-Dachshund Mix', 8.521739130434783, 11293.04275363031),
#  ("I Don't Know", 8.515981735159817, 20429.535692559653),
#  ('American Staffordshire Terrier-American Pit Bull Terrier Mix', 8.5, 62584.808332862376),
#  ('German Shorthaired Pointer-American Pit Bull Terrier Mix', 8.5, 200962.158335),
#  ('Boxer-Labrador Retriever Mix', 8.5, 7349.800925997322),
#  ('Akita-German Shepherd Dog Mix', 8.5, 21076.83333316665),
#  ('Berger Picard', 8.4, 119010.3299998916),
#  ('Cavalier King Charles Spaniel', 8.382978723404255, 24597.98014168833),
#  ('Standard Poodle', 8.372549019607844, 5242.120588262054),
#  ('Catahoula Leopard Dog-Australian Cattle Dog Mix', 8.333333333333334, 3360.955555679),
#  ('Border Collie-Siberian Husky Mix', 8.333333333333334, 2249.6555555702002),
#  ('Yorkshire Terrier-Miniature Schnauzer Mix', 8.333333333333334, 51683.28888889838),
#  ('Doberman Pinscher-Rottweiler Mix', 8.333333333333334, 13405.966666666667),
#  ('Border Collie-Australian Kelpie Mix', 8.333333333333334, 10846.300000101668),
#  ('Havanese', 8.309278350515465, 27587.313745718286),
#  ('Japanese Chin', 8.285714285714286, 6616.378571496715),
#  ('Maltese-Poodle Mix', 8.26923076923077, 26266.11314115417),
#  ('Boston Terrier', 8.247706422018348, 29032.33379215479),
#  ('Miniature Pinscher', 8.229166666666666, 22743.938888882145),
#  ('Greater Swiss Mountain Dog', 8.222222222222221, 4187.5851851843),
#  ('Chesapeake Bay Retriever', 8.210526315789474, 25840.13859631954),
#  ('Bulldog', 8.2, 24395.454814940385),
#  ('Boston Terrier-French Bulldog Mix', 8.2, 838.56999997072),
#  ('Bichon Frise-Poodle Mix', 8.136363636363637, 15169.633333374046),
#  ('Labrador Retriever-Australian Shepherd Mix', 8.1, 3498.83166670786),
#  ('Basenji', 8.071428571428571, 5844.720238108278),
#  ('Dachshund', 8.054545454545455, 25323.897979776855),
#  ('Great Dane', 8.0, 14073.50471696941),
#  ('American Staffordshire Terrier- Mix', 8.0, 43707.383332213336),
#  ('Poodle-German Spitz Mix', 8.0, 2541.75),
#  ('Boerboel', 8.0, 14856.5458332115),
#  ('Pembroke Welsh Corgi-Chihuahua Mix', 8.0, 9346.14166665),
#  ('Greyhound-American Pit Bull Terrier Mix', 8.0, 1552.6666668),
#  ('Rottweiler-American Pit Bull Terrier Mix', 8.0, 7294.952777817667),
#  ('Dachshund-American Staffordshire Terrier Mix', 8.0, 61569.483333),
#  ('Lhasa Apso-Tibetan Spaniel Mix', 8.0, 69295.133333),
#  ('Russell Terrier', 7.956521739130435, 40031.881522466174),
#  ('Yorkshire Terrier-Poodle Mix', 7.916666666666667, 19836.57430550711),
#  ('Yorkshire Terrier', 7.893939393939394, 17688.622222271835),
#  ('American Pit Bull Terrier-American Staffordshire Terrier Mix', 7.875, 19148.318749597875),
#  ('Pomeranian', 7.833333333333333, 38992.57291673115),
#  ('German Shepherd Dog-Australian Shepherd Mix', 7.833333333333333, 10165.636111174217),
#  ('Toy Fox Terrier', 7.833333333333333, 7992.422222290166),
#  ('Xoloitzcuintli', 7.8, 40578.82666661974),
#  ('German Shepherd Dog-Labrador Retriever Mix', 7.777777777777778, 11730.862962900446),
#  ('Poodle-Cocker Spaniel Mix', 7.75, 48978.49374999077),
#  ('Pekingese', 7.75, 7572.258333385236),
#  ('Australian Shepherd-Shetland Sheepdog Mix', 7.75, 43.64166665867499),
#  ('Chinese Crested', 7.7272727272727275, 10356.274242388663),
#  ('Beagle-Labrador Retriever Mix', 7.6923076923076925, 10261.508974340695),
#  ('Australian Shepherd-Border Collie Mix', 7.6875, 14537.572395812014),
#  ('Chihuahua', 7.681818181818182, 22974.670129846287),
#  ('Boxer-Bulldog Mix', 7.666666666666667, 7529.661111013001),
#  ('Border Collie-Newfoundland Mix', 7.666666666666667, 7305.461111105567),
#  ('Borzoi-Whippet Mix', 7.666666666666667, 188098.22777666667),
#  ('Golden Retriever-Border Collie Mix', 7.666666666666667, 15176.905555562602),
#  ('Parson Russell Terrier', 7.661538461538462, 34216.43641065125),
#  ('Poodle-Yorkshire Terrier Mix', 7.642857142857143, 28970.565476222342),
#  ('Labrador Retriever-Chinese Shar-Pei Mix', 7.6, 34324.58333265694),
#  ('Poodle-Bichon Frise Mix', 7.6, 25834.508333645084),
#  ('Eurasier', 7.6, 8720.589999974),
#  ('Labrador Retriever-Poodle Mix', 7.6, 31841.320833270824),
#  ('Bullmastiff', 7.538461538461538, 3588.5141025942844),
#  ('Australian Shepherd-Golden Retriever Mix', 7.5, 34433.3333332115),
#  ('Miniature Bull Terrier', 7.5, 78.26666660435),
#  ('Bearded Collie', 7.5, 26592.763095259666),
#  ('Havanese-Maltese Mix', 7.5, 3161.5333333175),
#  ('Chihuahua-Labrador Retriever Mix', 7.5, 23.5249999695),
#  ('Maltese', 7.409638554216867, 19142.75542172412),
#  ('Yorkshire Terrier-Bichon Frise Mix', 7.4, 10981.2233332496),
#  ('Cane Corso', 7.3076923076923075, 5783.550000065878),
#  ('Shih Tzu-Poodle Mix', 7.291666666666667, 4693.425000029275),
#  ('Czechoslovakian Vlcak', 7.25, 6843.70416675425),
#  ('Border Collie-Cocker Spaniel Mix', 7.25, 10054.55833325915),
#  ('Brussels Griffon', 7.235294117647059, 10163.07450981654),
#  ('Stabyhoun', 7.2, 9065.570000006359),
#  ('Leonberger', 7.181818181818182, 35304.32424279149),
#  ('Labrador Retriever-Greyhound Mix', 7.166666666666667, 4836.258333343084),
#  ('Belgian Sheepdog- Mix', 7.0, 13080.883333),
#  ('Border Collie-Belgian Tervuren Mix', 7.0, 24.416666663),
#  ('Staffordshire Bull Terrier-Great Dane Mix', 7.0, 31281.266667),
#  ('Staffordshire Bull Terrier-Miniature Schnauzer Mix', 7.0, 4243.2333333),
#  ('Great Dane-Irish Wolfhound Mix', 7.0, 25.483333415),
#  ('Pembroke Welsh Corgi-Great Pyrenees Mix', 7.0, 1518.9),
#  ('Dandie Dinmont Terrier', 7.0, 32.933333407),
#  ('Pointer-Beagle Mix', 7.0, 34.416666736),
#  ('Golden Retriever-English Cocker Spaniel Mix', 7.0, 894007.56667),
#  ('German Shepherd Dog-Chinese Shar-Pei Mix', 7.0, 23001.549999986),
#  ('Dogo Argentino', 7.0, 1507.816666692),
#  ('American Foxhound- Mix', 7.0, 32.94999998),
#  ('Bedlington Terrier-Whippet Mix', 7.0, 102391.53333),
#  ('Otterhound', 7.0, 177338.05),
#  ('Basset Hound-Russell Terrier Mix', 7.0, 31.333333366),
#  ('Airedale Terrier-Labrador Retriever Mix', 7.0, 5295.97499995),
#  ('Shih Tzu-Chihuahua Mix', 7.0, 2930.3333334),
#  ('Miniature Schnauzer-Maltese Mix', 7.0, 32036.066667),
#  ('Redbone Coonhound-Basset Hound Mix', 7.0, 20.816666748),
#  ('Doberman Pinscher-Pug Mix', 7.0, 22.449999931),
#  ('Bulldog-Chesapeake Bay Retriever Mix', 7.0, 14521.883333),
#  ('Catahoula Leopard Dog-Siberian Husky Mix', 7.0, 16470.833333),
#  ('Scottish Deerhound', 7.0, 6980.01666655),
#  ('-Toy Fox Terrier Mix', 7.0, 43648.266667),
#  ('German Shorthaired Pointer- Mix', 7.0, 260.93333339),
#  ('American Pit Bull Terrier-German Shepherd Dog Mix', 7.0, 39.466666671),
#  ('Lhasa Apso-Shih Tzu Mix', 7.0, 11329.166666649),
#  ('Mastiff-American Pit Bull Terrier Mix', 7.0, 57.633333374),
#  ('Scottish Terrier-Shih Tzu Mix', 7.0, 43066.55),
#  ('Russell Terrier-Cocker Spaniel Mix', 7.0, 1880.3166667),
#  ('Maltese-Pomeranian Mix', 7.0, 10045.783333),
#  ('Pointer-Australian Shepherd Mix', 7.0, 41.616666748),
#  ('Belgian Malinois- Mix', 7.0, 43.283333252),
#  ('American Eskimo Dog- Mix', 7.0, 4010.7666666),
#  ('Cardigan Welsh Corgi-Cairn Terrier Mix', 7.0, 31.566666606),
#  ('Basenji-Shiba Inu Mix', 7.0, 29.983333313),
#  ('Beagle-Whippet Mix', 7.0, 49057.466667),
#  ('French Bulldog-Pug Mix', 7.0, 44.566666671),
#  ('American Staffordshire Terrier-Chinese Shar-Pei Mix', 7.0, 51.300000024),
#  ('German Shepherd Dog-Whippet Mix', 7.0, 1559.8),
#  ('Border Collie-West Highland White Terrier Mix', 7.0, 34.150000008),
#  ('Pug-Russell Terrier Mix', 7.0, 68884.483333),
#  ('Australian Cattle Dog-Bluetick Coonhound Mix', 7.0, 1617.8166666),
#  ('American Foxhound-Labrador Retriever Mix', 7.0, 18520.216667),
#  ('Russell Terrier-Rat Terrier Mix', 7.0, 1315.6666666),
#  ('Australian Cattle Dog-Weimaraner Mix', 7.0, 51.233333215),
#  ('Siberian Husky-Standard Schnauzer Mix', 7.0, 15803.783333),
#  ('Labrador Retriever-Cocker Spaniel Mix', 7.0, 8687.800000078667),
#  ('Bichon Frise-Pomeranian Mix', 7.0, 17.933333464),
#  ('Border Collie-Kooikerhondje Mix', 7.0, 95412.766667),
#  ('Border Collie-Chow Chow Mix', 7.0, 50256.333333),
#  ('Border Terrier-Parson Russell Terrier Mix', 7.0, 1097.9333333),
#  ('Siberian Husky-Bernese Mountain Dog Mix', 7.0, 3005.75),
#  ('Black and Tan Coonhound-German Shepherd Dog Mix', 7.0, 40.116666667),
#  ('Havanese-Bichon Frise Mix', 7.0, 86561.4),
#  ('Boxer-Rhodesian Ridgeback Mix', 7.0, 22977.19444456667),
#  ('Great Pyrenees-Golden Retriever Mix', 7.0, 38.949999955),
#  ('American English Coonhound-Rhodesian Ridgeback Mix', 7.0, 104.61666668),
#  ('St. Bernard-Dachshund Mix', 7.0, 43044.616667),
#  ('Maltese-Cavalier King Charles Spaniel Mix', 7.0, 1475.9166668),
#  ('Chihuahua-Norwich Terrier Mix', 7.0, 4193.4666667),
#  ('American Staffordshire Terrier-Greyhound Mix', 7.0, 4329.6833333),
#  ('Basenji-Whippet Mix', 7.0, 18542.383333),
#  ('Plott-Beagle Mix', 7.0, 46.933333411),
#  ('Flat-Coated Retriever-Portuguese Water Dog Mix', 7.0, 11275.033333),
#  ('Miniature Pinscher-Russell Terrier Mix', 7.0, 51.583333329),
#  ('German Shepherd Dog-Bluetick Coonhound Mix', 7.0, 123823.55),
#  ('Wire Fox Terrier-Parson Russell Terrier Mix', 7.0, 1402.0666667),
#  ('Parson Russell Terrier-Cairn Terrier Mix', 7.0, 28918.733333),
#  ('Russell Terrier-Golden Retriever Mix', 7.0, 6783.7999999),
#  ('Boxer-Boston Terrier Mix', 7.0, 2999.3499999),
#  ('Akita-Bernese Mountain Dog Mix', 7.0, 133975.78333),
#  ('Basset Hound-Cardigan Welsh Corgi Mix', 7.0, 1926.5500001),
#  ('American Pit Bull Terrier-Chinese Shar-Pei Mix', 7.0, 565.28333333),
#  ('Karelian Bear Dog-Border Collie Mix', 7.0, 14088.183333),
#  ('Boxer-American Foxhound Mix', 7.0, 26.183333301),
#  ('Brittany-Siberian Husky Mix', 7.0, 5901.2000001),
#  ('Great Pyrenees-Chow Chow Mix', 7.0, 11114.85),
#  ('Papillon-Miniature Schnauzer Mix', 7.0, 62.266666553),
#  ('Papillon-Pomeranian Mix', 7.0, 11678.783333),
#  ('Border Collie-Affenpinscher Mix', 7.0, 28719.4),
#  ('Australian Labradoodle-Poodle Mix', 7.0, 40.958333295),
#  ('Japanese Chin-Pekingese Mix', 7.0, 48.98333335),
#  ('American Pit Bull Terrier-Vizsla Mix', 7.0, 1156.9166667),
#  ('Labrador Retriever-Pomeranian Mix', 7.0, 74.066666585),
#  ('Lhasa Apso-Dandie Dinmont Terrier Mix', 7.0, 1424.0333333),
#  ('Collie-Belgian Malinois Mix', 7.0, 195.4166667),
#  ('Chinese Shar-Pei-Australian Cattle Dog Mix', 7.0, 39.416666606),
#  ('Shetland Sheepdog-American Eskimo Dog Mix', 7.0, 36.933333333),
#  ('Golden Retriever-Irish Wolfhound Mix', 7.0, 70.00000002),
#  ('Lhasa Apso-German Shepherd Dog Mix', 7.0, 54.766666663),
#  ('Poodle-Redbone Coonhound Mix', 7.0, 19743.816667),
#  ('Chihuahua-Australian Terrier Mix', 7.0, 1625.8000001),
#  ('Australian Cattle Dog-Chow Chow Mix', 7.0, 28.099999967),
#  ('Brussels Griffon-Poodle Mix', 7.0, 2899.6166665),
#  ('Bulldog-Labrador Retriever Mix', 7.0, 7526.9833334),
#  ('Yorkshire Terrier-German Spitz Mix', 7.0, 28.933333309),
#  ('Dachshund-American Pit Bull Terrier Mix', 7.0, 497.75),
#  ('Bichon Frise-Havanese Mix', 7.0, 8684.5499999),
#  ('Pekingese-Lhasa Apso Mix', 7.0, 11781.633333),
#  ('Cocker Spaniel-English Cocker Spaniel Mix', 7.0, 73.349999955),
#  ('Brussels Griffon-Border Terrier Mix', 7.0, 1905.6),
#  ('German Shorthaired Pointer-Newfoundland Mix', 7.0, 15890.866667),
#  ('Plott-American Foxhound Mix', 7.0, 27535.066667),
#  ('Golden Retriever-Redbone Coonhound Mix', 7.0, 38.51666663),
#  ('Cairn Terrier-Australian Terrier Mix', 7.0, 35.266666654),
#  ('Jack Russell Terrier-Poodle Mix', 7.0, 1452.9000001),
#  ('Golden Retriever-Cavalier King Charles Spaniel Mix', 7.0, 106.0666667),
#  ('Bullmastiff-Dogue de Bordeaux Mix', 7.0, 26.549999829),
#  ('Smooth Fox Terrier-Bluetick Coonhound Mix', 7.0, 11373.3),
#  ('Australian Shepherd-Pug Mix', 7.0, 60.299999992),
#  ('Jack Russell Terrier', 6.985074626865671, 4775.877611951427),
#  ('Chihuahua-Miniature Pinscher Mix', 6.909090909090909, 100717.686363297),
#  ('Basset Hound', 6.777777777777778, 13810.607407514048),
#  ('Jack-A-Poo', 6.75, 2491.8416667237498),
#  ('Beagle-Rat Terrier Mix', 6.75, 3733.220833361775),
#  ('Australian Cattle Dog-American Pit Bull Terrier Mix', 6.666666666666667, 712.2555555447001),
#  ('Beagle-Cocker Spaniel Mix', 6.666666666666667, 16995.366666710066),
#  ('American Pit Bull Terrier-Labrador Retriever Mix', 6.631578947368421, 19481.734210362432),
#  ('Great Pyrenees', 6.615384615384615, 3155.057692336969),
#  ('Chihuahua- Mix', 6.5, 2162.9083332925),
#  ('Silky Terrier-Poodle Mix', 6.5, 20872.8499998475),
#  ('Canaan Dog', 6.5, 2134.4291666324248),
#  ('Australian Shepherd-Rottweiler Mix', 6.5, 7521.97500019),
#  ('Catahoula Leopard Dog-Labrador Retriever Mix', 6.5, 3433.099999997983),
#  ('Shih Tzu-Bichon Frise Mix', 6.5, 27633.727083359096),
#  ('German Shepherd Dog-Greyhound Mix', 6.5, 663.133333434),
#  ('Bull Terrier-Labrador Retriever Mix', 6.5, 26.883333362000002),
#  ('Mastiff-Great Dane Mix', 6.5, 4907.7250000529),
#  ('Bichon Frise-Lhasa Apso Mix', 6.5, 5000.5916667),
#  ('Poodle-English Springer Spaniel Mix', 6.5, 110938.808331685),
#  ('Boxer-American Pit Bull Terrier Mix', 6.375, 1856.825000016475),
#  ('Chow Chow', 6.375, 1643.2833333003748),
#  ('Labrador Retriever-American Staffordshire Terrier Mix', 6.333333333333333, 35.16111105533333),
#  ('Staffordshire Bull Terrier', 6.275862068965517, 19407.399425577212),
#  ('Doberman Pinscher-Labrador Retriever Mix', 6.25, 44129.98750092075),
#  ('American Staffordshire Terrier-Boxer Mix', 6.25, 10038.160416639874),
#  ('Tibetan Terrier', 6.2105263157894735, 20465.304386123844),
#  ('Black Russian Terrier', 6.2, 6532.36333332436),
#  ('Schipperke', 6.111111111111111, 112997.01481371357),
#  ('Boykin Spaniel-Deutscher Wachtelhund Mix', 6.0, 469837.46667),
#  ('Staffordshire Bull Terrier-Russell Terrier Mix', 6.0, 118.96666663),
#  ('German Spitz', 6.0, 2398.3571428399287),
#  ('Boxer-Bull Terrier Mix', 6.0, 2861.5166667),
#  ('Russell Terrier- Mix', 6.0, 37.899999951),
#  ('St. Bernard- Mix', 6.0, 8795.0666666),
#  ('Beagle-Siberian Husky Mix', 6.0, 52.283333394),
#  ('Shih Tzu-Silky Terrier Mix', 6.0, 10127.35),
#  ('Rat Terrier-Beagle Mix', 6.0, 4860.1333333),
#  ('Beagle-Border Collie Mix', 6.0, 30374.55000048797),
#  ('Irish Setter-Border Collie Mix', 6.0, 162873.06667),
#  ('Golden Retriever-Cocker Spaniel Mix', 6.0, 30.516666684999997),
#  ('Labrador Retriever-Pembroke Welsh Corgi Mix', 6.0, 38576.516667),
#  ('Cardigan Welsh Corgi-Lancashire Heeler Mix', 6.0, 30.799999906),
#  ('Chihuahua-Toy Fox Terrier Mix', 6.0, 12072.0416665),
#  ('Pekingese-Cocker Spaniel Mix', 6.0, 35.816666691),
#  ('Labrador Retriever-Great Pyrenees Mix', 6.0, 164.16666672),
#  ('Plott-Boxer Mix', 6.0, 1441.1833335),
#  ('Rottweiler-Collie Mix', 6.0, 133.0166667),
#  ('Miniature Australian Shepherd-Poodle Mix', 6.0, 7315.1166666),
#  ('Australian Cattle Dog-Australian Kelpie Mix', 6.0, 656.59999989),
#  ('Miniature Schnauzer-Soft Coated Wheaten Terrier Mix', 6.0, 30.849999972),
#  ('Jack Russell Terrier-Smooth Fox Terrier Mix', 6.0, 1037.8833333),
#  ('Jindo-Shiba Inu Mix', 6.0, 11377.65),
#  ('Golden Retriever-German Shepherd Dog Mix', 5.875, 17821.204166728836),
#  ('Dachshund-Chihuahua Mix', 5.875, 46674.25208372161),
#  ('Italian Greyhound', 5.84, 22453.784000250555),
#  ('Dachshund-Miniature Pinscher Mix', 5.75, 3980.462500099775),
#  ('Chihuahua-Rat Terrier Mix', 5.75, 4791.822916656138),
#  ('Small Munsterlander Pointer', 5.666666666666667, 536.049999961),
#  ('Bulldog-Boxer Mix', 5.666666666666667, 11511.366666866665),
#  ('Airedale Terrier', 5.6, 8848.045833323717),
#  ('Staffordshire Bull Terrier-Bulldog Mix', 5.5, 21.2583332785),
#  ('Labrador Retriever-English Springer Spaniel Mix', 5.5, 20.108333227499998),
#  ('Labrador Retriever-St. Bernard Mix', 5.5, 337124.9583317195),
#  ('Dogue de Bordeaux', 5.5, 26.0749999715),
#  ('Australian Shepherd-Labrador Retriever Mix', 5.5, 3082.6059523550502),
#  ('St. Bernard-Border Collie Mix', 5.5, 37.37500003645),
#  ('Siberian Husky-Beagle Mix', 5.5, 46750.233333481505),
#  ('Australian Shepherd-Siberian Husky Mix', 5.5, 5765.875000013751),
#  ('Australian Shepherd-Collie Mix', 5.5, 2272.84999995),
#  ('Jack Russell Terrier-American Pit Bull Terrier Mix', 5.5, 24.149999934500002),
#  ('Poodle-Shih Tzu Mix', 5.363636363636363, 23802.11515146701),
#  ('Beagle-Australian Cattle Dog Mix', 5.333333333333333, 5873.472222149001),
#  ('BullBoxer', 5.333333333333333, 1196.4138888647833),
#  ('Collie-Labrador Retriever Mix', 5.333333333333333, 2113.0222222326333),
#  ('Jindo', 5.333333333333333, 548.544444421),
#  ('Boxer-Border Collie Mix', 5.0, 21.516666634),
#  ('German Shepherd Dog-Chow Chow Mix', 5.0, 23248.17083336166),
#  ('Bugg', 5.0, 112331.2083333495),
#  ('Lakeland Terrier', 5.0, 36929.62222226667),
#  ('Chesapeake Bay Retriever-Beagle Mix', 5.0, 21.799999939),
#  ('Cairn Terrier-Shih Tzu Mix', 5.0, 532847.1),
#  ('Pharaoh Hound', 5.0, 3720.06666658945),
#  ('Pug-Lhasa Apso Mix', 5.0, 1433.3166667),
#  ('American Foxhound', 5.0, 119877.97222336032),
#  ('Rat Terrier- Mix', 5.0, 12.566666736),
#  ('Boxer-Jindo Mix', 5.0, 1864.0500001),
#  ('Bolognese', 5.0, 20713.555555514733),
#  ('Staffordshire Bull Terrier-Bullmastiff Mix', 5.0, 752.2249999625001),
#  ('Boxer-Great Dane Mix', 5.0, 127.13333343),
#  ('Barbet', 5.0, 38718.316667),
#  ('Border Collie-Standard Schnauzer Mix', 5.0, 81998.0),
#  ('Yorkshire Terrier-Soft Coated Wheaten Terrier Mix', 5.0, 32.333333305),
#  ('Great Dane-Doberman Pinscher Mix', 5.0, 23.950000016),
#  ('Giant Schnauzer-Standard Poodle Mix', 5.0, 797.624999964),
#  ('Poodle-English Cocker Spaniel Mix', 5.0, 1417.2000001),
#  ('Poodle-Newfoundland Mix', 5.0, 11897.716667),
#  ('Labrador Retriever-Standard Poodle Mix', 5.0, 368.88888890466666),
#  ('American Eskimo Dog-Pembroke Welsh Corgi Mix', 5.0, 7024.0999999),
#  ('Border Collie-Icelandic Sheepdog Mix', 5.0, 4567.8833334),
#  ('Bernese Mountain Dog-Chow Chow Mix', 5.0, 539.75000002),
#  ('Labrador Retriever-Chow Chow Mix', 4.8, 21.146666698399997),
#  ('Chihuahua-Pomeranian Mix', 4.777777777777778, 6865.642592560745),
#  ('Dachshund-Beagle Mix', 4.75, 1867.96666660275),
#  ('Saluki', 4.75, 107.816666715),
#  ('Rottweiler-German Shepherd Dog Mix', 4.714285714285714, 43850.690476182375),
#  ('Beagle-Russell Terrier Mix', 4.5, 2568.574999964425),
#  ('Dachshund-Parson Russell Terrier Mix', 4.5, 11.3916666547),
#  ('German Shepherd Dog-Redbone Coonhound Mix', 4.5, 13686.791666834999),
#  ('Bulldog-American Pit Bull Terrier Mix', 4.5, 3589.4833333785),
#  ('Flat-Coated Retriever-Border Collie Mix', 4.5, 16.80833327635),
#  ('Belgian Malinois-Dutch Shepherd Mix', 4.5, 145.091666664),
#  ('Poodle-German Shepherd Dog Mix', 4.5, 1450.72500001465),
#  ('Anatolian Shepherd Dog-Great Pyrenees Mix', 4.5, 25.95000006485),
#  ('Standard Poodle-Golden Retriever Mix', 4.5, 8682.075000185001),
#  ('Chihuahua-Jack Russell Terrier Mix', 4.5, 5026.5500000517),
#  ('Jack Russell Terrier-Rat Terrier Mix', 4.5, 2216.737500034625),
#  ('German Shepherd Dog-Norwegian Elkhound Mix', 4.5, 2967.6666666813),
#  ('German Shorthaired Pointer-Pointer Mix', 4.5, 18773.825000217552),
#  ('Border Collie-Bluetick Coonhound Mix', 4.5, 20.1000000265),
#  ('Boxer-German Shepherd Dog Mix', 4.333333333333333, 16.605555508266665),
#  ('Basset Hound-Labrador Retriever Mix', 4.333333333333333, 6250.3444443196995),
#  ('Miniature Schnauzer-Yorkshire Terrier Mix', 4.333333333333333, 433.48333339633336),
#  ('Parson Russell Terrier-Beagle Mix', 4.0, 8.9166667521),
#  ('Russell Terrier-Pug Mix', 4.0, 35945.333333),
#  ('Bulldog-Beagle Mix', 4.0, 10.383333337),
#  ('Russell Terrier-Chihuahua Mix', 4.0, 9.7166666016),
#  ('American Staffordshire Terrier-Catahoula Leopard Dog Mix', 4.0, 15.416666695),
#  ('Whippet-Chinese Shar-Pei Mix', 4.0, 11.800000037),
#  ('Labrador Retriever-Basset Hound Mix', 4.0, 11.366666532),
#  ('Poodle-Standard Schnauzer Mix', 4.0, 4348.19166662115),
#  ('Boxer-Bloodhound Mix', 4.0, 10.699999967),
#  ('Australian Shepherd-Chow Chow Mix', 4.0, 14.000000004),
#  ('Pembroke Welsh Corgi-American Eskimo Dog Mix', 4.0, 12.683333268),
#  ('English Cocker Spaniel-Poodle Mix', 4.0, 11.200000106),
#  ('Border Collie- Mix', 4.0, 11.466666579049999),
#  ('Shiba Inu-Pembroke Welsh Corgi Mix', 4.0, 18.799999951),
#  ('Papillon-Japanese Chin Mix', 4.0, 24.833333248),
#  ('Russell Terrier-Poodle Mix', 4.0, 1016.3500001),
#  ('Italian Greyhound-Cardigan Welsh Corgi Mix', 4.0, 9.4499998698),
#  ('Maltese-Cocker Spaniel Mix', 4.0, 9.2499999512),
#  ('-Australian Cattle Dog Mix', 4.0, 14.550000041),
#  ('Bloodhound-Irish Setter Mix', 4.0, 9.5000001058),
#  ('Maltese-Standard Schnauzer Mix', 4.0, 13.98333326),
#  ('Papillon-Poodle Mix', 4.0, 10.950000114),
#  ('Boxer-Russell Terrier Mix', 4.0, 15.616666618),
#  ('Chihuahua-Shiba Inu Mix', 4.0, 11.616666690999999),
#  ('German Shepherd Dog- Mix', 4.0, 26.611111165666667),
#  ('Beagle-Pointer Mix', 4.0, 6.5499998413),
#  ('Border Collie-American Eskimo Dog Mix', 4.0, 8.550000061),
#  ('Whippet-Russell Terrier Mix', 4.0, 39838.383333),
#  ('Pomeranian-Chihuahua Mix', 4.0, 382.12666668419996),
#  ('Boxer-Greyhound Mix', 4.0, 12.316666577),
#  ('German Shepherd Dog-Mastiff Mix', 4.0, 8.8833334351),
#  ('Rhodesian Ridgeback-Redbone Coonhound Mix', 4.0, 21624.1),
#  ('Catahoula Leopard Dog-American Pit Bull Terrier Mix', 4.0, 14.483333228),
#  ...]

# %% [markdown]
# **Question 5: Write a query that outputs the average amount of time it took customers to complete each type of test where any individual reaction times over 6000 hours are excluded and only average reaction times that are greater than 0 seconds are included (your output should end up with 67 rows).**

# %%
# %%sql
# SELECT test_name,AVG(TIMEDIFF(end_time,start_time))
# FROM exam_answers
# WHERE TIMESTAMPDIFF(hour, start_time, end_time) BETWEEN 0 and 6000
# GROUP BY test_name;
# Out:
# 67 rows affected.
# [('1 vs 1 Game', 14.4173998045),
#  ('3 vs 1 Game', 14.0040376851),
#  ('5 vs 1 Game', 13.3626153229),
#  ('Activity', 95058.8457510636),
#  ('Arm Pointing', 3236.3478048165),
#  ('Attachment', 22669.891879753),
#  ('Confinement', 41961.580658269),
#  ('Cover Your Eyes', 7340.3659221613),
#  ('Delayed Cup Game', 5357.2413081369),
#  ('Diet', 142772.1429509057),
#  ('Different Perspective', 540.3945205479),
#  ('Emotions', 15206.6345029796),
#  ('Environment', 4187.0251436782),
#  ('Excitability', 20668.9325545076),
#  ('Expression Game', 12.6964285714),
#  ('Eye Contact Game', 7460.231967563),
#  ('Eye Contact Warm-up', 7293.94641731),
#  ('Foot Pointing', 3118.6475840774),
#  ('Gender', 26916.4949148233),
#  ('Impossible Task Game', 1977.1396648045),
#  ('Impossible Task Warm-up', 14113.4844835572),
#  ('Inferential Reasoning Game', 3424.0164752871),
#  ('Inferential Reasoning Warm-up', 6755.9560565807),
#  ('Memory versus Pointing', 1433.0018383377),
#  ('Memory versus Smell', 8659.025386558),
#  ('Navigation Game', 1305.8704225352),
#  ('Navigation Learning', 2289.7449392713),
#  ('Navigation Warm-up', 32654.3659825239),
#  ('Numerosity Warm-Up', 18638.7153895686),
#  ('Obedience', 7317.125165457),
#  ('One Cup Warm-up', 5869.6147289866),
#  ('Owner', 24237.064414242),
#  ('Partnership', 7404.5567293322),
#  ('Perception', 8986.3867344925),
#  ('Physical', 28277.5030561703),
#  ('Physical Reasoning Game', 842.1516115966),
#  ('Physical Reasoning Warm-up', 1492.006476387),
#  ('Purina', 8929.0139906088),
#  ('Purina-Only', 12981.4019701303),
#  ('Puzzles', 9014.0404763122),
#  ('Recall', 8809.8946365299),
#  ('Self Control Game', 10.4134199134),
#  ('Set 1', 30982.795505618),
#  ('Set 2', 1310.6083916084),
#  ('Set 3', 41188.5425373134),
#  ('Shaker Game', 8.4322580645),
#  ('Shaker Warm-Up', 669.6656441718),
#  ('Shared Perspective', 27.5786350148),
#  ('Shy/Boldness', 24018.8599930137),
#  ('Slide', 5373.4353070175),
#  ('Smell Game', 8279.8729064039),
#  ('Sociability', 72183.784268334),
#  ('Social', 27467.7614519521),
#  ('Social-Quiz', 427858.993718849),
#  ('Stair Game', 3057.637829912),
#  ('Surprise And Delight', 55483.1289263403),
#  ('Switch', 545.3526570048),
#  ('Toys', 12504.3499452355),
#  ('Training', 12553.6579995349),
#  ('Treat Warm-up', 10695.8919993399),
#  ('Turn Your Back', 5264.0318673489),
#  ('Two Cup Warm-up', 1244.8387411168),
#  ('Warm-Up', 8126.7998296422),
#  ('Watching', 50053.1181860902),
#  ('Watching - Part 2', 7757.6625816993),
#  ('Yawn Game', 19028.8915701416),
#  ('Yawn Warm-up', 83275.4342419294)]

# %% [markdown]
# **Question 6: Write a query that outputs the total number of unique User_Guids in each combination of State and ZIP code (postal code) in the United States, sorted first by state name in ascending alphabetical order, and second by total number of unique User_Guids in descending order (your first state should be AE and there should be 5043 rows in total in your output).**

# %%
# %%sql
# SELECT state, zip, COUNT(user_guid)
# FROM users
# WHERE country='US'
# GROUP BY state, zip
# ORDER BY state ASC, 1 DESC;
# Out:
# 5043 rows affected.
# [('AE', '9128', 3),
#  ('AE', '9053', 1),
#  ('AE', '9107', 1),
#  ('AE', '9845', 1),
#  ('AE', '9469', 1),
#  ('AK', '99501', 2),
#  ('AK', '99712', 1),
#  ('AK', '99752', 1),
#  ('AK', '99709', 3),
#  ('AK', '99611', 1),
#  ('AK', '99577', 3),
#  ('AK', '99645', 1),
#  ('AK', '99705', 1),
#  ('AK', '99518', 1),
#  ('AK', '99824', 1),
#  ('AK', '99775', 1),
#  ('AK', '99507', 3),
#  ('AK', '99676', 1),
#  ('AK', '99509', 1),
#  ('AK', '99928', 1),
#  ('AK', '99587', 1),
#  ('AK', '99502', 1),
#  ('AK', '99516', 1),
#  ('AK', '99567', 1),
#  ('AL', '36375', 1),
#  ('AL', '36604', 1),
#  ('AL', '35674', 1),
#  ('AL', '36303', 1),
#  ('AL', '36609', 2),
#  ('AL', '36832', 1),
#  ('AL', '36116', 2),
#  ('AL', '35121', 1),
#  ('AL', '35216', 1),
#  ('AL', '35760', 1),
#  ('AL', '35976', 1),
#  ('AL', '35209', 4),
#  ('AL', '35803', 1),
#  ('AL', '35906', 3),
#  ('AL', '35476', 2),
#  ('AL', '36104', 1),
#  ('AL', '35004', 1),
#  ('AL', '35758', 1),
#  ('AL', '35007', 1),
#  ('AL', '36527', 1),
#  ('AL', '35801', 3),
#  ('AL', '35763', 1),
#  ('AL', '35205', 1),
#  ('AL', '36695', 1),
#  ('AL', '35242', 2),
#  ('AL', '36561', 1),
#  ('AL', '35646', 1),
#  ('AL', '36532', 2),
#  ('AL', '35662', 1),
#  ('AL', '36203', 1),
#  ('AL', '35094', 1),
#  ('AL', '36037', 1),
#  ('AL', '35179', 1),
#  ('AL', '35405', 1),
#  ('AL', '36801', 1),
#  ('AL', '36106', 1),
#  ('AL', '36602', 1),
#  ('AP', '96377', 1),
#  ('AP', '96367', 1),
#  ('AP', '96205', 2),
#  ('AP', '96310', 2),
#  ('AR', '72042', 1),
#  ('AR', '72207', 3),
#  ('AR', '71913', 1),
#  ('AR', '72762', 1),
#  ('AR', '72401', 3),
#  ('AR', '72206', 1),
#  ('AR', '72034', 1),
#  ('AR', '72714', 1),
#  ('AR', '72113', 1),
#  ('AR', '72712', 2),
#  ('AR', '72212', 1),
#  ('AR', '72632', 2),
#  ('AR', '72554', 1),
#  ('AR', '72704', 1),
#  ('AR', '72908', 1),
#  ('AR', '72802', 1),
#  ('AR', '72703', 2),
#  ('AR', '72058', 1),
#  ('AR', '71909', 3),
#  ('AR', '72201', 1),
#  ('AR', '72202', 1),
#  ('AR', '72223', 2),
#  ('AR', '72631', 1),
#  ('AR', '72701', 1),
#  ('AR', '72135', 1),
#  ('AR', '72901', 1),
#  ('AR', '72756', 1),
#  ('AR', '72015', 1),
#  ('AR', '72956', 1),
#  ('AZ', '85635', 2),
#  ('AZ', '85028', 3),
#  ('AZ', '85615', 2),
#  ('AZ', '85308', 1),
#  ('AZ', '85029', 2),
#  ('AZ', '85745', 2),
#  ('AZ', '85140', 1),
#  ('AZ', '85636', 1),
#  ('AZ', '85711', 5),
#  ('AZ', '85254', 5),
#  ('AZ', '85257', 3),
#  ('AZ', '85715', 2),
#  ('AZ', '85737', 3),
#  ('AZ', '85718', 6),
#  ('AZ', '85719', 4),
#  ('AZ', '85281', 2),
#  ('AZ', '85716', 4),
#  ('AZ', '85021', 3),
#  ('AZ', '85749', 5),
#  ('AZ', '85646', 1),
#  ('AZ', '85042', 3),
#  ('AZ', '85282', 3),
#  ('AZ', '85385', 1),
#  ('AZ', '85048', 3),
#  ('AZ', '85622', 1),
#  ('AZ', '85203', 2),
#  ('AZ', '85614', 1),
#  ('AZ', '85086', 2),
#  ('AZ', '86351', 3),
#  ('AZ', '85353', 1),
#  ('AZ', '85283', 3),
#  ('AZ', '85032', 5),
#  ('AZ', 'N/A', 4),
#  ('AZ', '85027', 1),
#  ('AZ', '85710', 1),
#  ('AZ', '85266', 4),
#  ('AZ', '85202', 2),
#  ('AZ', '85251', 2),
#  ('AZ', '86426', 1),
#  ('AZ', '85743', 1),
#  ('AZ', '85739', 2),
#  ('AZ', '85253', 5),
#  ('AZ', '85233', 3),
#  ('AZ', '86303', 19),
#  ('AZ', '85365', 1),
#  ('AZ', '85730', 1),
#  ('AZ', '85296', 3),
#  ('AZ', '85641', 1),
#  ('AZ', '85303', 3),
#  ('AZ', '86403', 1),
#  ('AZ', '85044', 3),
#  ('AZ', '85205', 1),
#  ('AZ', '85255', 3),
#  ('AZ', '85704', 2),
#  ('AZ', '85128', 1),
#  ('AZ', '85006', 1),
#  ('AZ', '85045', 2),
#  ('AZ', '85013', 1),
#  ('AZ', '85207', 1),
#  ('AZ', '86305', 3),
#  ('AZ', '85050', 1),
#  ('AZ', '85392', 3),
#  ('AZ', '85209', 2),
#  ('AZ', '85382', 1),
#  ('AZ', '85304', 2),
#  ('AZ', '85260', 5),
#  ('AZ', '85016', 2),
#  ('AZ', '85008', 1),
#  ('AZ', '85250', 4),
#  ('AZ', '85012', 1),
#  ('AZ', '85143', 2),
#  ('AZ', '85069', 1),
#  ('AZ', '86002', 1),
#  ('AZ', '85024', 3),
#  ('AZ', '86312', 1),
#  ('AZ', '86336', 1),
#  ('AZ', '86504', 1),
#  ('AZ', '85750', 5),
#  ('AZ', '85284', 1),
#  ('AZ', '86314', 2),
#  ('AZ', '85120', 1),
#  ('AZ', '86301', 1),
#  ('AZ', '85748', 3),
#  ('AZ', '85658', 1),
#  ('AZ', '85249', 2),
#  ('AZ', '86327', 1),
#  ('AZ', '85212', 1),
#  ('AZ', '85138', 2),
#  ('AZ', '85327', 1),
#  ('AZ', '85015', 1),
#  ('AZ', '85083', 1),
#  ('AZ', '85020', 1),
#  ('AZ', '85022', 3),
#  ('AZ', '85374', 2),
#  ('AZ', '86323', 1),
#  ('AZ', '85338', 1),
#  ('AZ', '85340', 1),
#  ('AZ', '85712', 2),
#  ('AZ', '86326', 1),
#  ('AZ', '85119', 1),
#  ('AZ', '85335', 1),
#  ('AZ', '85262', 1),
#  ('AZ', '85210', 2),
#  ('AZ', '85122', 1),
#  ('AZ', '85118', 1),
#  ('AZ', '85650', 1),
#  ('AZ', '85268', 1),
#  ('AZ', '85206', 2),
#  ('AZ', '85286', 1),
#  ('AZ', '85259', 2),
#  ('AZ', '85755', 1),
#  ('AZ', '85248', 1),
#  ('AZ', '85226', 1),
#  ('CA', '95003', 5),
#  ('CA', '90046', 14),
#  ('CA', '95620', 3),
#  ('CA', '91001', 5),
#  ('CA', '90045', 2),
#  ('CA', '94952', 8),
#  ('CA', '92116', 4),
#  ('CA', '91301', 9),
#  ('CA', '94607', 3),
#  ('CA', '93924', 3),
#  ('CA', '92071', 8),
#  ('CA', '92886', 5),
#  ('CA', '92612', 4),
#  ('CA', '94306', 5),
#  ('CA', '94939', 2),
#  ('CA', '96022', 2),
#  ('CA', '94704', 1),
#  ('CA', '92694', 2),
#  ('CA', '94129', 2),
#  ('CA', '90803', 7),
#  ('CA', '91104', 2),
#  ('CA', '92104', 2),
#  ('CA', '94010', 3),
#  ('CA', '94114', 10),
#  ('CA', '92037', 3),
#  ('CA', '94707', 2),
#  ('CA', '95678', 2),
#  ('CA', '90048', 1),
#  ('CA', '92618', 3),
#  ('CA', '90210', 5),
#  ('CA', '91931', 1),
#  ('CA', '90031', 1),
#  ('CA', '94107', 12),
#  ('CA', '93010', 3),
#  ('CA', '95123', 1),
#  ('CA', '92130', 14),
#  ('CA', '95119', 2),
#  ('CA', '94941', 9),
#  ('CA', '90266', 8),
#  ('CA', '91355', 2),
#  ('CA', '94611', 9),
#  ('CA', '90274', 6),
#  ('CA', '93908', 2),
#  ('CA', '95407', 4),
#  ('CA', '93534', 1),
#  ('CA', '93023', 6),
#  ('CA', '95110', 2),
#  ('CA', '93003', 7),
#  ('CA', '94025', 10),
#  ('CA', '94110', 10),
#  ('CA', '91101', 3),
#  ('CA', '91030', 4),
#  ('CA', '94117', 7),
#  ('CA', '91602', 1),
#  ('CA', '94501', 4),
#  ('CA', '93654', 2),
#  ('CA', '94061', 6),
#  ('CA', '93308', 2),
#  ('CA', '90039', 8),
#  ('CA', '94002', 3),
#  ('CA', '93463', 1),
#  ('CA', '94519', 2),
#  ('CA', '92038', 1),
#  ('CA', '95621', 4),
#  ('CA', '92009', 7),
#  ('CA', '91423', 2),
#  ('CA', '92672', 6),
#  ('CA', '92046', 1),
#  ('CA', '93955', 4),
#  ('CA', '90049', 8),
#  ('CA', '95536', 1),
#  ('CA', '95005', 2),
#  ('CA', '90041', 1),
#  ('CA', '94568', 4),
#  ('CA', '92107', 17),
#  ('CA', '93923', 2),
#  ('CA', '92118', 1),
#  ('CA', '94041', 2),
#  ('CA', '95818', 5),
#  ('CA', '94015', 3),
#  ('CA', '94089', 2),
#  ('CA', '90405', 6),
#  ('CA', '91406', 5),
#  ('CA', '90403', 3),
#  ('CA', '91106', 2),
#  ('CA', '94602', 8),
#  ('CA', '95695', 4),
#  ('CA', '94102', 1),
#  ('CA', '92603', 3),
#  ('CA', '94965', 4),
#  ('CA', '95112', 2),
#  ('CA', '94131', 8),
#  ('CA', '95065', 2),
#  ('CA', '94127', 4),
#  ('CA', '94609', 3),
#  ('CA', '94970', 1),
#  ('CA', '90034', 4),
#  ('CA', '92003', 2),
#  ('CA', '90042', 1),
#  ('CA', '95030', 3),
#  ('CA', '94040', 5),
#  ('CA', '94510', 6),
#  ('CA', '92307', 1),
#  ('CA', '95062', 3),
#  ('CA', '90066', 2),
#  ('CA', '92211', 5),
#  ('CA', '92057', 5),
#  ('CA', '94402', 1),
#  ('CA', '92126', 4),
#  ('CA', '92880', 2),
#  ('CA', '95401', 5),
#  ('CA', '91702', 1),
#  ('CA', '90051', 1),
#  ('CA', '91711', 2),
#  ('CA', '94597', 6),
#  ('CA', '95076', 1),
#  ('CA', '90402', 2),
#  ('CA', '91942', 5),
#  ('CA', '91941', 4),
#  ('CA', '92506', 2),
#  ('CA', '92660', 4),
#  ('CA', '94027', 3),
#  ('CA', '94608', 2),
#  ('CA', '90019', 1),
#  ('CA', '90292', 7),
#  ('CA', '92320', 1),
#  ('CA', '92067', 4),
#  ('CA', '90503', 4),
#  ('CA', '94109', 5),
#  ('CA', '93012', 6),
#  ('CA', '95356', 1),
#  ('CA', '94121', 8),
#  ('CA', '90230', 1),
#  ('CA', '90068', 8),
#  ('CA', '91791', 1),
#  ('CA', '92024', 11),
#  ('CA', '94502', 2),
#  ('CA', '90211', 5),
#  ('CA', '90212', 4),
#  ('CA', '90291', 7),
#  ('CA', '95616', 5),
#  ('CA', '93402', 3),
#  ('CA', '91606', 3),
#  ('CA', '93021', 2),
#  ('CA', '92128', 4),
#  ('CA', '92835', 2),
#  ('CA', '90065', 5),
#  ('CA', '94558', 4),
#  ('CA', '92649', 4),
#  ('CA', '94901', 6),
#  ('CA', '91204', 1),
#  ('CA', '92373', 2),
#  ('CA', '92129', 4),
#  ('CA', '94954', 2),
#  ('CA', '95648', 3),
#  ('CA', '95476', 5),
#  ('CA', '92040', 1),
#  ('CA', '93561', 5),
#  ('CA', '92109', 4),
#  ('CA', '95472', 4),
#  ('CA', '95409', 2),
#  ('CA', '95630', 3),
#  ('CA', '94526', 2),
#  ('CA', '92592', 3),
#  ('CA', '94024', 2),
#  ('CA', '95682', 3),
#  ('CA', '94591', 1),
#  ('CA', '94595', 1),
#  ('CA', '92115', 4),
#  ('CA', '92054', 2),
#  ('CA', '95448', 3),
#  ('CA', '92688', 1),
#  ('CA', '95624', 1),
#  ('CA', '95404', 5),
#  ('CA', '94949', 3),
#  ('CA', '95864', 1),
#  ('CA', '95811', 1),
#  ('CA', '95008', 6),
#  ('CA', '92707', 1),
#  ('CA', '95037', 2),
#  ('CA', '90024', 4),
#  ('CA', '90232', 5),
#  ('CA', '91303', 1),
#  ('CA', '94904', 6),
#  ('CA', '91730', 3),
#  ('CA', '92780', 2),
#  ('CA', '94044', 1),
#  ('CA', '91377', 1),
#  ('CA', '94550', 5),
#  ('CA', '94536', 4),
#  ('CA', '94599', 1),
#  ('CA', '91321', 3),
#  ('CA', '92504', 1),
#  ('CA', '93562', 1),
#  ('CA', '92028', 1),
#  ('CA', '94951', 1),
#  ('CA', '95762', 6),
#  ('CA', '93401', 2),
#  ('CA', '95046', 1),
#  ('CA', '92595', 1),
#  ('CA', '92106', 5),
#  ('CA', '95403', 4),
#  ('CA', '95747', 1),
#  ('CA', '90731', 3),
#  ('CA', '93940', 5),
#  ('CA', '95032', 3),
#  ('CA', '95618', 3),
#  ('CA', '92007', 1),
#  ('CA', '94301', 2),
#  ('CA', '95608', 5),
#  ('CA', '95014', 6),
#  ('CA', '94920', 2),
#  ('CA', '94928', 3),
#  ('CA', '95010', 2),
#  ('CA', '92101', 6),
#  ('CA', '90720', 6),
#  ('CA', '90004', 4),
#  ('CA', '91214', 1),
#  ('CA', '91750', 1),
#  ('CA', '94903', 6),
#  ('CA', '95722', 1),
#  ('CA', '95134', 2),
#  ('CA', '92059', 1),
#  ('CA', '90277', 6),
#  ('CA', '94706', 5),
#  ('CA', '92026', 5),
#  ('CA', '93063', 3),
#  ('CA', '94703', 5),
#  ('CA', '95227', 1),
#  ('CA', '91775', 1),
#  ('CA', '91356', 1),
#  ('CA', '91041', 1),
#  ('CA', '95354', 2),
#  ('CA', '90814', 1),
#  ('CA', '93422', 3),
#  ('CA', '92014', 2),
#  ('CA', '90807', 4),
#  ('CA', '91302', 2),
#  ('CA', '95833', 1),
#  ('CA', '93536', 2),
#  ('CA', '95116', 1),
#  ('CA', '92008', 3),
#  ('CA', '93117', 1),
#  ('CA', '91324', 1),
#  ('CA', '94118', 5),
#  ('CA', '94708', 1),
#  ('CA', '93458', 2),
#  ('CA', '95070', 2),
#  ('CA', '90069', 8),
#  ('CA', '90026', 5),
#  ('CA', '95492', 3),
#  ('CA', '95819', 3),
#  ('CA', '91607', 2),
#  ('CA', '94542', 1),
#  ('CA', '91326', 1),
#  ('CA', '95650', 2),
#  ('CA', '94404', 1),
#  ('CA', '94585', 1),
#  ('CA', '93711', 3),
#  ('CA', '92651', 1),
#  ('CA', '92103', 6),
#  ('CA', '94506', 4),
#  ('CA', '90278', 7),
#  ('CA', '92122', 5),
#  ('CA', '90404', 4),
#  ('CA', '94134', 1),
#  ('CA', '92691', 3),
#  ('CA', '91786', 4),
#  ('CA', '94115', 3),
#  ('CA', '90064', 3),
#  ('CA', '96104', 1),
#  ('CA', '94062', 6),
#  ('CA', '91921', 1),
#  ('CA', '92867', 3),
#  ('CA', '92708', 1),
#  ('CA', '91307', 4),
#  ('CA', '95816', 2),
#  ('CA', '90016', 1),
#  ('CA', '93035', 3),
#  ('CA', '92124', 2),
#  ('CA', '93643', 1),
#  ('CA', '92123', 2),
#  ('CA', '95125', 4),
#  ('CA', '94553', 2),
#  ('CA', '92545', 3),
#  ('CA', '91913', 1),
#  ('CA', '92656', 5),
#  ('CA', '94559', 2),
#  ('CA', '90020', 1),
#  ('CA', '90071', 1),
#  ('CA', '94606', 1),
#  ('CA', '90704', 1),
#  ('CA', '93546', 3),
#  ('CA', '94551', 4),
#  ('CA', '92131', 3),
#  ('CA', '94018', 1),
#  ('CA', '92262', 1),
#  ('CA', '91335', 2),
#  ('CA', '92637', 1),
#  ('CA', '92027', 1),
#  ('CA', '94564', 2),
#  ('CA', '95033', 2),
#  ('CA', '94132', 2),
#  ('CA', '94520', 1),
#  ('CA', '92117', 5),
#  ('CA', '92019', 4),
#  ('CA', '92078', 5),
#  ('CA', '95540', 1),
#  ('CA', '91320', 4),
#  ('CA', '95132', 1),
#  ('CA', '91945', 2),
#  ('CA', '92610', 1),
#  ('CA', '94930', 2),
#  ('CA', '94549', 6),
#  ('CA', '94925', 1),
#  ('CA', '94523', 4),
#  ('CA', '92075', 2),
#  ('CA', '95926', 4),
#  ('CA', '95470', 1),
#  ('CA', '91105', 2),
#  ('CA', '92807', 1),
#  ('CA', '92870', 1),
#  ('CA', '93312', 1),
#  ('CA', '91403', 3),
#  ('CA', '92516', 1),
#  ('CA', '92110', 2),
#  ('CA', '90504', 1),
#  ('CA', '94063', 1),
#  ('CA', '92657', 2),
#  ('CA', '94618', 3),
#  ('CA', '95212', 1),
#  ('CA', '95124', 2),
#  ('CA', '95138', 1),
#  ('CA', '92626', 2),
#  ('CA', '93907', 3),
#  ('CA', '94583', 4),
#  ('CA', '92011', 1),
#  ('CA', '90272', 2),
#  ('CA', '94947', 1),
#  ('CA', '91367', 4),
#  ('CA', '91776', 1),
#  ('CA', '95945', 1),
#  ('CA', '94565', 1),
#  ('CA', '95677', 1),
#  ('CA', '91364', 3),
#  ('CA', '93953', 2),
#  ('CA', '94521', 3),
#  ('CA', '96003', 1),
#  ('CA', '92270', 2),
#  ('CA', '92105', 2),
#  ('CA', '94571', 1),
#  ('CA', '91505', 2),
#  ('CA', '94960', 2),
#  ('CA', '93447', 1),
#  ('CA', '93722', 1),
#  ('CA', '91016', 1),
#  ('CA', '91405', 1),
#  ('CA', '95746', 1),
#  ('CA', '94556', 1),
#  ('CA', '92629', 3),
#  ('CA', '94619', 4),
#  ('CA', '92673', 2),
#  ('CA', '92606', 2),
#  ('CA', '92064', 10),
#  ('CA', '92677', 4),
#  ('CA', '91387', 2),
#  ('CA', '94103', 1),
#  ('CA', '96141', 1),
#  ('CA', '95765', 1),
#  ('CA', '93550', 1),
#  ('CA', '94955', 1),
#  ('CA', '92091', 1),
#  ('CA', '90290', 3),
#  ('CA', '92562', 4),
#  ('CA', '93230', 4),
#  ('CA', '91208', 3),
#  ('CA', '95965', 1),
#  ('CA', '95437', 2),
#  ('CA', '95051', 4),
#  ('CA', '90265', 5),
#  ('CA', '90036', 6),
#  ('CA', '92143', 2),
#  ('CA', '90401', 1),
#  ('CA', '95691', 2),
#  ('CA', '95460', 2),
#  ('CA', '90808', 3),
#  ('CA', '94605', 1),
#  ('CA', '90029', 2),
#  ('CA', '95405', 1),
#  ('CA', '93150', 1),
#  ('CA', '90755', 2),
#  ('CA', '93105', 5),
#  ('CA', '92065', 2),
#  ('CA', '95482', 2),
#  ('CA', '94545', 1),
#  ('CA', '92646', 3),
#  ('CA', '91501', 2),
#  ('CA', '93036', 2),
#  ('CA', '92881', 2),
#  ('CA', '93444', 4),
#  ('CA', '92120', 2),
#  ('CA', '94070', 2),
#  ('CA', '94538', 1),
#  ('CA', '92503', 2),
#  ('CA', '93710', 1),
#  ('CA', '93446', 1),
#  ('CA', '92223', 1),
#  ('CA', '95503', 1),
#  ('CA', '91205', 1),
#  ('CA', '96073', 2),
#  ('CA', '94560', 1),
#  ('CA', '95603', 1),
#  ('CA', '95628', 1),
#  ('CA', '95633', 1),
#  ('CA', '92058', 1),
#  ('CA', '92232', 1),
#  ('CA', '91042', 2),
#  ('CA', '91207', 2),
#  ('CA', '92586', 1),
#  ('CA', '95694', 1),
#  ('CA', '93108', 1),
#  ('CA', '91748', 1),
#  ('CA', '90012', 2),
#  ('CA', '93405', 1),
#  ('CA', '90027', 6),
#  ('CA', '92056', 3),
#  ('CA', '95128', 1),
#  ('CA', '95465', 1),
#  ('CA', '94566', 2),
#  ('CA', '94574', 1),
#  ('CA', '92163', 1),
#  ('CA', '91737', 1),
#  ('CA', '95843', 2),
#  ('CA', '93103', 4),
#  ('CA', '91354', 2),
#  ('CA', '94303', 1),
#  ('CA', '94123', 6),
#  ('CA', '91801', 1),
#  ('CA', '92627', 2),
#  ('CA', '94133', 2),
#  ('CA', '95959', 2),
#  ('CA', '92020', 2),
#  ('CA', '94304', 1),
#  ('CA', '92025', 2),
#  ('CA', '90025', 5),
#  ('CA', '94702', 1),
#  ('CA', '93291', 2),
#  ('CA', '94116', 3),
#  ('CA', '94403', 4),
#  ('CA', '92092', 1),
#  ('CA', '94563', 3),
#  ('CA', '94022', 2),
#  ('CA', '95060', 1),
#  ('CA', '93013', 2),
#  ('CA', '96067', 1),
#  ('CA', '94503', 1),
#  ('CA', '93225', 1),
#  ('CA', '94963', 1),
#  ('CA', '94577', 1),
#  ('CA', '94705', 3),
#  ('CA', '96002', 1),
#  ('CA', '92084', 4),
#  ('CA', '94528', 2),
#  ('CA', '93065', 3),
#  ('CA', '94507', 2),
#  ('CA', '94087', 1),
#  ('CA', '92806', 1),
#  ('CA', '94080', 1),
#  ('CA', '90242', 1),
#  ('CA', '95834', 1),
#  ('CA', '91701', 1),
#  ('CA', '93110', 2),
#  ('CA', '95442', 1),
#  ('CA', '90005', 1),
#  ('CA', '90247', 1),
#  ('CA', '92869', 1),
#  ('CA', '90015', 1),
#  ('CA', '94590', 1),
#  ('CA', '94547', 1),
#  ('CA', '90815', 2),
#  ('CA', '90638', 2),
#  ('CA', '94158', 2),
#  ('CA', '94122', 1),
#  ('CA', '94534', 2),
#  ('CA', '93041', 3),
#  ('CA', '92111', 3),
#  ('CA', '91325', 1),
#  ('CA', '91311', 3),
#  ('CA', '91011', 1),
#  ('CA', '95831', 1),
#  ('CA', '95113', 1),
#  ('CA', '93637', 1),
#  ('CA', '93309', 2),
#  ('CA', '94505', 2),
#  ('CA', '90017', 1),
#  ('CA', '94966', 1),
#  ('CA', '95519', 1),
#  ('CA', '94582', 2),
#  ('CA', '92831', 1),
#  ('CA', '92127', 1),
#  ('CA', '93611', 1),
#  ('CA', '90813', 2),
#  ('CA', '94014', 1),
#  ('CA', '95688', 1),
#  ('CA', '96107', 1),
#  ('CA', '92072', 2),
#  ('CA', '95136', 3),
#  ('CA', '94544', 2),
#  ('CA', '92081', 5),
#  ('CA', '92247', 1),
#  ('CA', '95355', 1),
#  ('CA', '94588', 1),
#  ('CA', '91316', 1),
#  ('CA', 'N/A', 2),
#  ('CA', '92675', 3),
#  ('CA', '92102', 2),
#  ('CA', '92119', 1),
#  ('CA', '95120', 1),
#  ('CA', '91502', 2),
#  ('CA', '92683', 1),
#  ('CA', '93311', 1),
#  ('CA', '95835', 2),
#  ('CA', '95018', 1),
#  ('CA', '95605', 1),
#  ('CA', '94580', 1),
#  ('CA', '94530', 2),
#  ('CA', '94043', 1),
#  ('CA', '90810', 1),
#  ('CA', '92705', 1),
#  ('CA', '94598', 3),
#  ('CA', '94531', 1),
#  ('CA', '91764', 1),
#  ('CA', '91910', 1),
#  ('CA', '92663', 2),
#  ('CA', '92021', 1),
#  ('CA', '94555', 1),
#  ('CA', '90077', 1),
#  ('CA', '94546', 1),
#  ('CA', '92701', 1),
#  ('CA', '92653', 2),
#  ('CA', '90014', 1),
#  ('CA', '93730', 1),
#  ('CA', '92374', 1),
#  ('CA', '93292', 1),
#  ('CA', '91604', 2),
#  ('CA', '96161', 2),
#  ('CA', '93428', 1),
#  ('CA', '95602', 1),
#  ('CA', '91902', 1),
#  ('CA', '93726', 1),
#  ('CA', '95692', 1),
#  ('CA', '90043', 1),
#  ('CA', '92263', 1),
#  ('CA', '95570', 1),
#  ('CA', '92593', 1),
#  ('CA', '92782', 2),
#  ('CA', '95949', 1),
#  ('CA', '90740', 1),
#  ('CA', '93443', 1),
#  ('CA', '92010', 2),
#  ('CA', '91755', 1),
#  ('CA', '95425', 1),
#  ('CA', '94515', 2),
#  ('CA', '95023', 3),
#  ('CA', '92602', 1),
#  ('CA', '91901', 1),
#  ('CA', '95457', 2),
#  ('CA', '91908', 1),
#  ('CA', '93257', 1),
#  ('CA', '96001', 3),
#  ('CA', '91361', 1),
#  ('CA', '93420', 1),
#  ('CA', '92590', 1),
#  ('CA', '91789', 1),
#  ('CA', '92865', 1),
#  ('CA', '91723', 1),
#  ('CA', '91770', 2),
#  ('CA', '91006', 1),
#  ('CA', '96145', 1),
#  ('CA', '92692', 2),
#  ('CA', '91203', 1),
#  ('CA', '93619', 1),
#  ('CA', '92549', 1),
#  ('CA', '95020', 1),
#  ('CA', '92647', 2),
#  ('CA', '95050', 1),
#  ('CA', '94709', 1),
#  ('CA', '93720', 1),
#  ('CA', '93452', 1),
#  ('CA', '95366', 2),
#  ('CA', '96151', 1),
#  ('CA', '95501', 1),
#  ('CA', '92648', 1),
#  ('CA', '93243', 1),
#  ('CA', '90804', 1),
#  ('CA', '90806', 1),
#  ('CA', '92260', 1),
#  ('CA', '95383', 1),
#  ('CA', '95361', 2),
#  ('CA', '90293', 1),
#  ('CA', '91436', 1),
#  ('CA', '94011', 1),
#  ('CA', '92620', 1),
#  ('CA', '91201', 1),
#  ('CA', '95436', 1),
#  ('CA', '94610', 2),
#  ('CA', '91411', 1),
#  ('CA', '94112', 1),
#  ('CA', '94539', 2),
#  ('CA', '94518', 1),
#  ('CA', '92821', 1),
#  ('CA', '94086', 1),
#  ('CA', '92253', 1),
#  ('CA', '94596', 1),
#  ('CA', '90067', 1),
#  ('CA', '93549', 2),
#  ('CA', '95236', 1),
#  ('CA', '95610', 1),
#  ('CA', '92625', 1),
#  ('CO', '80525', 3),
#  ('CO', '80304', 14),
#  ('CO', '81236', 1),
#  ('CO', '80401', 5),
#  ('CO', '81403', 1),
#  ('CO', '80113', 2),
#  ('CO', '80827', 3),
#  ('CO', '80138', 3),
#  ('CO', '81131', 1),
#  ('CO', '80013', 1),
#  ('CO', '81007', 1),
#  ('CO', '80122', 1),
#  ('CO', '81625', 1),
#  ('CO', '81621', 1),
#  ('CO', '80487', 1),
#  ('CO', '80303', 7),
#  ('CO', '80602', 1),
#  ('CO', '80015', 3),
#  ('CO', '80127', 5),
#  ('CO', '80829', 1),
#  ('CO', '81201', 1),
#  ('CO', '80223', 1),
#  ('CO', '80111', 4),
#  ('CO', '80005', 2),
#  ('CO', '80026', 4),
#  ('CO', '80206', 5),
#  ('CO', '80542', 1),
#  ('CO', '80534', 1),
#  ('CO', '80537', 1),
#  ('CO', '80222', 2),
#  ('CO', '80002', 1),
#  ('CO', '80132', 4),
#  ('CO', '81601', 4),
#  ('CO', '80403', 8),
#  ('CO', '80120', 2),
#  ('CO', '80126', 5),
#  ('CO', '80911', 1),
#  ('CO', '80922', 4),
#  ('CO', '80644', 1),
#  ('CO', '80134', 5),
#  ('CO', '80014', 4),
#  ('CO', '80227', 7),
#  ('CO', '80439', 4),
#  ('CO', '80634', 1),
#  ('CO', '80237', 5),
#  ('CO', '80301', 2),
#  ('CO', '80923', 2),
#  ('CO', '80012', 1),
#  ('CO', '80112', 3),
#  ('CO', '81501', 2),
#  ('CO', '80203', 2),
#  ('CO', '80516', 2),
#  ('CO', '80212', 3),
#  ('CO', '80202', 1),
#  ('CO', '80210', 11),
#  ('CO', '80233', 1),
#  ('CO', '81507', 1),
#  ('CO', '81620', 4),
#  ('CO', '80906', 4),
#  ('CO', '80218', 2),
#  ('CO', '80020', 7),
#  ('CO', '80302', 3),
#  ('CO', '80205', 5),
#  ('CO', '80908', 2),
#  ('CO', '80430', 1),
#  ('CO', '81301', 4),
#  ('CO', '80234', 2),
#  ('CO', '80919', 2),
#  ('CO', '80209', 1),
#  ('CO', '80011', 1),
#  ('CO', '80247', 2),
#  ('CO', '80215', 1),
#  ('CO', '80022', 1),
#  ('CO', '81639', 1),
#  ('CO', '80526', 7),
#  ('CO', '80524', 2),
#  ('CO', '80918', 2),
#  ('CO', '80010', 1),
#  ('CO', '80466', 1),
#  ('CO', '80121', 1),
#  ('CO', '80204', 1),
#  ('CO', '81623', 2),
#  ('CO', '80207', 1),
#  ('CO', '80016', 1),
#  ('CO', '80004', 2),
#  ('CO', '80129', 2),
#  ('CO', '80116', 1),
#  ('CO', '80528', 1),
#  ('CO', '80501', 4),
#  ('CO', '80104', 1),
#  ('CO', '81252', 1),
#  ('CO', '80023', 1),
#  ('CO', '80521', 4),
#  ('CO', '80230', 1),
#  ('CO', '80517', 1),
#  ('CO', '80808', 2),
#  ('CO', '80238', 2),
#  ('CO', '80128', 6),
#  ('CO', '80904', 3),
#  ('CO', '80211', 4),
#  ('CO', '80021', 5),
#  ('CO', '80917', 2),
#  ('CO', '81652', 1),
#  ('CO', '80503', 4),
#  ('CO', '80631', 1),
#  ('CO', '80108', 1),
#  ('CO', '80228', 1),
#  ('CO', '80220', 6),
#  ('CO', '80124', 1),
#  ('CO', '80504', 1),
#  ('CO', '80422', 1),
#  ('CO', '80488', 1),
#  ('CO', '81235', 1),
#  ('CO', '80962', 1),
#  ('CO', '80027', 3),
#  ('CO', '80643', 1),
#  ('CO', '80527', 1),
#  ('CO', '80226', 1),
#  ('CO', '80033', 2),
#  ('CO', '80107', 1),
#  ('CO', '81611', 4),
#  ('CO', '80308', 1),
#  ('CO', '80465', 3),
#  ('CO', '80109', 1),
#  ('CO', '80216', 1),
#  ('CO', '80214', 2),
#  ('CO', '80864', 4),
#  ('CO', '80106', 1),
#  ('CO', '80547', 1),
#  ('CO', '80000', 1),
#  ('CO', '80498', 1),
#  ('CO', '80540', 1),
#  ('CO', '80813', 1),
#  ('CO', '80123', 1),
#  ('CO', '80031', 1),
#  ('CT', '6820', 6),
#  ('CT', '6234', 2),
#  ('CT', '6371', 4),
#  ('CT', '6489', 3),
#  ('CT', '6078', 2),
#  ('CT', '6401', 1),
#  ('CT', '6440', 2),
#  ('CT', '6239', 1),
#  ('CT', '6840', 8),
#  ('CT', '6853', 2),
#  ('CT', '6902', 4),
#  ('CT', '6830', 2),
#  ('CT', '6880', 8),
#  ('CT', '6824', 6),
#  ('CT', '6517', 3),
#  ('CT', '6512', 2),
#  ('CT', '6480', 2),
#  ('CT', '6851', 3),
#  ('CT', '6776', 4),
#  ('CT', '6612', 2),
#  ('CT', '6001', 2),
#  ('CT', '6831', 1),
#  ('CT', '6801', 1),
#  ('CT', '6226', 1),
#  ('CT', '6811', 2),
#  ('CT', '6878', 1),
#  ('CT', '6518', 1),
#  ('CT', '6410', 3),
#  ('CT', '6357', 1),
#  ('CT', '6511', 2),
#  ('CT', '6268', 1),
#  ('CT', '6365', 1),
#  ('CT', '6043', 1),
#  ('CT', '6037', 1),
#  ('CT', '6013', 1),
#  ('CT', '6040', 2),
#  ('CT', '6422', 2),
#  ('CT', '6478', 2),
#  ('CT', '6010', 2),
#  ...]

# %% [markdown]
# **Question 7: Write a query that outputs the total number of unique User_Guids in each combination of State and ZIP code in the United States *that have at least 5 users*, sorted first by state name in ascending alphabetical order, and second by total number of unique User_Guids in descending order (your first state/ZIP code combination should be AZ/86303).**

# %%
# %%sql
# SELECT state, zip, COUNT(user_guid)
# FROM users
# WHERE country='US'
# GROUP BY state, zip
# HAVING COUNT(user_guid)>4
# ORDER BY state ASC, 1 DESC;
# Out:
# 377 rows affected.
# [('AZ', '85711', 5),
#  ('AZ', '85254', 5),
#  ('AZ', '85718', 6),
#  ('AZ', '85749', 5),
#  ('AZ', '85032', 5),
#  ('AZ', '85253', 5),
#  ('AZ', '86303', 19),
#  ('AZ', '85260', 5),
#  ('AZ', '85750', 5),
#  ('CA', '95003', 5),
#  ('CA', '90046', 14),
#  ('CA', '91001', 5),
#  ('CA', '94952', 8),
#  ('CA', '91301', 9),
#  ('CA', '92071', 8),
#  ('CA', '92886', 5),
#  ('CA', '94306', 5),
#  ('CA', '90803', 7),
#  ('CA', '94114', 10),
#  ('CA', '90210', 5),
#  ('CA', '94107', 12),
#  ('CA', '92130', 14),
#  ('CA', '94941', 9),
#  ('CA', '90266', 8),
#  ('CA', '94611', 9),
#  ('CA', '90274', 6),
#  ('CA', '93023', 6),
#  ('CA', '93003', 7),
#  ('CA', '94025', 10),
#  ('CA', '94110', 10),
#  ('CA', '94117', 7),
#  ('CA', '94061', 6),
#  ('CA', '90039', 8),
#  ('CA', '92009', 7),
#  ('CA', '92672', 6),
#  ('CA', '90049', 8),
#  ('CA', '92107', 17),
#  ('CA', '95818', 5),
#  ('CA', '90405', 6),
#  ('CA', '91406', 5),
#  ('CA', '94602', 8),
#  ('CA', '94131', 8),
#  ('CA', '94040', 5),
#  ('CA', '94510', 6),
#  ('CA', '92211', 5),
#  ('CA', '92057', 5),
#  ('CA', '95401', 5),
#  ('CA', '94597', 6),
#  ('CA', '91942', 5),
#  ('CA', '90292', 7),
#  ('CA', '94109', 5),
#  ('CA', '93012', 6),
#  ('CA', '94121', 8),
#  ('CA', '90068', 8),
#  ('CA', '92024', 11),
#  ('CA', '90211', 5),
#  ('CA', '90291', 7),
#  ('CA', '95616', 5),
#  ('CA', '90065', 5),
#  ('CA', '94901', 6),
#  ('CA', '95476', 5),
#  ('CA', '93561', 5),
#  ('CA', '95404', 5),
#  ('CA', '95008', 6),
#  ('CA', '90232', 5),
#  ('CA', '94904', 6),
#  ('CA', '94550', 5),
#  ('CA', '95762', 6),
#  ('CA', '92106', 5),
#  ('CA', '93940', 5),
#  ('CA', '95608', 5),
#  ('CA', '95014', 6),
#  ('CA', '92101', 6),
#  ('CA', '90720', 6),
#  ('CA', '94903', 6),
#  ('CA', '90277', 6),
#  ('CA', '94706', 5),
#  ('CA', '92026', 5),
#  ('CA', '94703', 5),
#  ('CA', '94118', 5),
#  ('CA', '90069', 8),
#  ('CA', '90026', 5),
#  ('CA', '92103', 6),
#  ('CA', '90278', 7),
#  ('CA', '92122', 5),
#  ('CA', '94062', 6),
#  ('CA', '92656', 5),
#  ('CA', '92117', 5),
#  ('CA', '92078', 5),
#  ('CA', '94549', 6),
#  ('CA', '92064', 10),
#  ('CA', '90265', 5),
#  ('CA', '90036', 6),
#  ('CA', '93105', 5),
#  ('CA', '90027', 6),
#  ('CA', '94123', 6),
#  ('CA', '90025', 5),
#  ('CA', '92081', 5),
#  ('CO', '80304', 14),
#  ('CO', '80401', 5),
#  ('CO', '80303', 7),
#  ('CO', '80127', 5),
#  ('CO', '80206', 5),
#  ('CO', '80403', 8),
#  ('CO', '80126', 5),
#  ('CO', '80134', 5),
#  ('CO', '80227', 7),
#  ('CO', '80237', 5),
#  ('CO', '80210', 11),
#  ('CO', '80020', 7),
#  ('CO', '80205', 5),
#  ('CO', '80526', 7),
#  ('CO', '80128', 6),
#  ('CO', '80021', 5),
#  ('CO', '80220', 6),
#  ('CT', '6820', 6),
#  ('CT', '6840', 8),
#  ('CT', '6880', 8),
#  ('CT', '6824', 6),
#  ('CT', '6614', 5),
#  ('DC', '20002', 9),
#  ('DC', '20003', 5),
#  ('DC', '20001', 7),
#  ('DC', '20005', 6),
#  ('DC', '20007', 8),
#  ('DC', '20009', 14),
#  ('DC', '20016', 7),
#  ('DC', '20011', 6),
#  ('DE', '19958', 7),
#  ('FL', '32312', 6),
#  ('FL', '34698', 5),
#  ('FL', '33435', 5),
#  ('FL', '33477', 5),
#  ('FL', '33139', 5),
#  ('FL', '32566', 7),
#  ('FL', '33156', 5),
#  ('FL', '32765', 5),
#  ('FL', '32751', 5),
#  ('FL', '33647', 8),
#  ('FL', '33312', 5),
#  ('FL', '34134', 5),
#  ('FL', '33418', 6),
#  ('FL', '32821', 5),
#  ('GA', '30345', 6),
#  ('GA', '30328', 5),
#  ('GA', '30316', 5),
#  ('GA', '30067', 7),
#  ('GA', '30004', 7),
#  ('GA', '30305', 7),
#  ('GA', '30308', 5),
#  ('HI', '96734', 9),
#  ('ID', '83702', 9),
#  ('IL', '60093', 5),
#  ('IL', '60626', 5),
#  ('IL', '60614', 18),
#  ('IL', '60618', 6),
#  ('IL', '60657', 10),
#  ('IL', '60610', 7),
#  ('IL', '60640', 9),
#  ('IL', '60660', 7),
#  ('IL', '60201', 5),
#  ('IL', '60647', 6),
#  ('IL', '60613', 8),
#  ('IL', '60654', 12),
#  ('IL', '60642', 5),
#  ('IN', '47401', 6),
#  ('KS', '66062', 7),
#  ('KY', '41017', 5),
#  ('KY', '40222', 5),
#  ('LA', '70115', 8),
#  ('LA', '70118', 6),
#  ('MA', '2116', 5),
#  ('MA', '2129', 6),
#  ('MA', '2127', 8),
#  ('MA', '2135', 5),
#  ('MA', '2130', 5),
#  ('MA', '2143', 5),
#  ('MA', '2472', 5),
#  ('MD', '21286', 6),
#  ('MD', '20817', 7),
#  ('MD', '20895', 5),
#  ('MD', '20878', 6),
#  ('MD', '20854', 8),
#  ('MD', '21044', 5),
#  ('MD', '20910', 8),
#  ('MD', '21230', 5),
#  ('MD', '21228', 5),
#  ('MD', '20852', 5),
#  ('MI', '48105', 5),
#  ('MI', '48103', 8),
#  ('MI', '48307', 6),
#  ('MN', '55426', 6),
#  ('MO', '63122', 5),
#  ('MO', '63139', 8),
#  ('MT', '59715', 6),
#  ('N/A', 'N/A', 105),
#  ('NC', '27606', 16),
#  ('NC', '27278', 13),
#  ('NC', '27713', 11),
#  ('NC', '27707', 22),
#  ('NC', '27519', 10),
#  ('NC', '27701', 36),
#  ('NC', '27614', 7),
#  ('NC', '27615', 11),
#  ('NC', '27514', 11),
#  ('NC', '27705', 27),
#  ('NC', '27513', 7),
#  ('NC', '27517', 11),
#  ('NC', '27511', 6),
#  ('NC', '27612', 7),
#  ('NC', '27613', 11),
#  ('NC', '27616', 5),
#  ('NC', '27609', 9),
#  ('NC', '27607', 6),
#  ('NC', '27516', 17),
#  ('NC', '27410', 6),
#  ('NC', '28277', 5),
#  ('NC', '27502', 5),
#  ('NC', '27104', 40),
#  ('NC', '28205', 5),
#  ('NC', '28027', 7),
#  ('NC', '27617', 11),
#  ('NC', '28387', 5),
#  ('NC', '28374', 6),
#  ('NC', '27608', 8),
#  ('NC', '27603', 9),
#  ('NC', '28226', 5),
#  ('NC', '28787', 7),
#  ('NC', '27539', 9),
#  ('NC', '28270', 7),
#  ('NC', '28025', 5),
#  ('NC', '27106', 5),
#  ('NC', '27587', 7),
#  ('NC', '28734', 5),
#  ('NH', '3290', 5),
#  ('NJ', '7302', 7),
#  ('NJ', '8540', 5),
#  ('NJ', '7931', 5),
#  ('NJ', '7030', 9),
#  ('NJ', '8758', 5),
#  ('NM', '87111', 9),
#  ('NV', '89511', 6),
#  ('NY', '10023', 13),
#  ('NY', '10001', 5),
#  ('NY', '10028', 11),
#  ('NY', '10003', 14),
#  ('NY', '10022', 5),
#  ('NY', '10014', 8),
#  ('NY', '11201', 12),
#  ('NY', '10025', 12),
#  ('NY', '11105', 5),
#  ('NY', '10075', 5),
#  ('NY', '11215', 5),
#  ('NY', '10514', 5),
#  ('NY', '11211', 6),
#  ('NY', '10583', 6),
#  ('NY', '10013', 6),
#  ('NY', '10024', 13),
#  ('NY', '10019', 9),
#  ('NY', '11209', 5),
#  ('NY', '11222', 5),
#  ('NY', '10012', 6),
#  ('NY', '10803', 5),
#  ('NY', '14850', 9),
#  ('NY', '11238', 9),
#  ('NY', '10016', 11),
#  ('NY', '11249', 7),
#  ('NY', '11217', 6),
#  ('NY', '10708', 5),
#  ('NY', '10011', 9),
#  ('NY', '10021', 8),
#  ('NY', '10128', 7),
#  ('OH', '43214', 8),
#  ('OH', '45243', 5),
#  ('OH', '43068', 5),
#  ('OH', '43235', 6),
#  ('OH', '44149', 5),
#  ('OH', '45040', 6),
#  ('OK', '73112', 5),
#  ('OK', '73013', 8),
#  ('OR', '97239', 6),
#  ('OR', '97405', 6),
#  ('OR', '97701', 5),
#  ('OR', '97203', 5),
#  ('OR', '97212', 7),
#  ('OR', '97229', 9),
#  ('OR', '97215', 5),
#  ('OR', '97702', 5),
#  ('OR', '97206', 5),
#  ('PA', '19147', 6),
#  ('PA', '15237', 8),
#  ('PA', '15101', 5),
#  ('PA', '19460', 6),
#  ('PA', '19087', 6),
#  ('PA', '16066', 5),
#  ('PA', '15215', 5),
#  ('PA', '16052', 5),
#  ('PA', '17011', 5),
#  ('PA', '19335', 6),
#  ('SC', '29205', 6),
#  ('SC', '29707', 5),
#  ('SC', '29303', 14),
#  ('SC', '29464', 13),
#  ('SC', '29455', 5),
#  ('SC', '29407', 5),
#  ('TN', '37027', 6),
#  ('TN', '37204', 7),
#  ('TN', '37067', 9),
#  ('TN', '37128', 5),
#  ('TN', '37215', 5),
#  ('TN', '37205', 8),
#  ('TX', '77382', 7),
#  ('TX', '75214', 5),
#  ('TX', '77008', 8),
#  ('TX', '78723', 6),
#  ('TX', '75023', 5),
#  ('TX', '78703', 10),
#  ('TX', '77006', 5),
#  ('TX', '78745', 8),
#  ('TX', '78750', 10),
#  ('TX', '77546', 6),
#  ('TX', '77584', 7),
#  ('TX', '77007', 7),
#  ('TX', '78613', 5),
#  ('TX', '75022', 6),
#  ('TX', '76712', 5),
#  ('TX', '75248', 5),
#  ('TX', '78704', 6),
#  ('TX', '75025', 5),
#  ('TX', '78748', 5),
#  ('TX', '78660', 5),
#  ('TX', '78757', 6),
#  ('TX', '77381', 6),
#  ('TX', '75219', 6),
#  ('UT', '84109', 5),
#  ('UT', '84098', 7),
#  ('UT', '84093', 5),
#  ('VA', '22903', 9),
#  ('VA', '22201', 9),
#  ('VA', '22304', 6),
#  ('VA', '22602', 5),
#  ('VA', '22101', 6),
#  ('VA', '20120', 6),
#  ('VA', '22301', 6),
#  ('VA', '20147', 7),
#  ('VA', '22043', 8),
#  ('VA', '20105', 11),
#  ('VA', '22314', 8),
#  ('VA', '20170', 5),
#  ('VA', '20191', 9),
#  ('VA', '23435', 5),
#  ('VA', '22030', 5),
#  ('VA', '22902', 5),
#  ('VA', '20176', 5),
#  ('VA', '20148', 5),
#  ('VA', '23462', 7),
#  ('VA', '23185', 5),
#  ('WA', '98110', 5),
#  ('WA', '98052', 7),
#  ('WA', '98225', 7),
#  ('WA', '98115', 6),
#  ('WA', '98118', 9),
#  ('WA', '98072', 9),
#  ('WA', '98033', 8),
#  ('WA', '98122', 7),
#  ('WA', '98074', 6),
#  ('WA', '98112', 5),
#  ('WA', '98199', 7),
#  ('WA', '98103', 10),
#  ('WA', '98102', 8),
#  ('WA', '98045', 6),
#  ('WA', '98106', 5),
#  ('WA', '98038', 5),
#  ('WA', '98370', 5),
#  ('WI', '53718', 5),
#  ('WI', '53515', 8),
#  ('WI', '53213', 5)]

# %% [markdown]
# <mark>**Be sure to watch the next video before beginning Exercise 6, the next set of MySQL exercises</mark>,** **and feel free to practice any other queries you wish below!**
